# %%
import re
def create_a_character_table(newick):
    taxa = sorted(taxon for taxon in re.split('[(),]+', newick.rstrip(';')) if taxon)

    # find all the locations of pairs of matching parentheses
    stack = []
    match = []
    for j in range(len(newick)):
        if newick[j] == '(':
            stack.append(j)
        if newick[j] == ')':
            i = stack.pop()
            match.append((i, j))

    table = []
    for (i, j) in match[:-1]:
        subset = [taxon for taxon in re.split('[(),]+', newick[i:j+1]) if taxon]
        array = [int(taxa[k] in subset) for k in range(len(taxa))]
        table.append(''.join(map(str, array)))
    return table

# %%
newick = '(lobster,(cat,dog),(caterpillar,(elephant,mouse)));'

taxa = sorted(taxon for taxon in re.split('[(),]+', newick.rstrip(';')) if taxon)

chtblist = create_a_character_table(newick)

print(taxa)

print(chtblist)

# %%
newick = '(((((Abantias_chuatsi,((((Apus_japonensis,Megophrys_boulengeri),Varanus_parvus),Gyps_glutinosus),Coenobita_adspersus)),Epipedobates_naumanni),Alectoris_piscator),(Hottentotta_percnopterus,Phrynohyas_meermani)),((((((((((((((((((((((((((((((((((((((((((((((((((Abantias_flavolineata,Tylototriton_odoratus),(((((((((((Alcedo_pica,Glareola_multituberculatus),Boa_corone),Mabuya_interpres),Cyriopagopus_cyanochloris),Anthropoidae_tridactylum),(Motacilla_turneri,Phormictopus_bengkuluensis)),((((((((Anthropoides_hungaricus,Eudrornias_brandtii),Tropidurus_limosa),Pyrrhocorax_helvetica),(Himantopus_adamsii,Melanocoryhpa_aspera)),Rissa_coturnix),Nemorhaedus_smaragdina),Hadogenes_citreola),((Apodora_gibbosus,Arctomys_leptochelis),((((Leptobrachium_grandis,Nemorhaedus_fiber),Paramesotriton_hodgsoni),Ziphius_quinquestriatus),Pachydactylus_parahybana)))),(((Calidris_caudatus,crecca_papuana),Uncia_meles),Moschus_colombianus)),(Aythia_diadema,(((((Coenobita_cristatella,Gekko_himantopus),Underwoodisaurus_percnopterus),Epicrates_dahurica),(Geochelone_armata,Numenius_japonensis)),Nemorhaedus_haliaetus))),Bronchocela_stimsoni),Philomachus_vulgaris)),Holaspis_tigris),((Aegialites_rhymnus,(Limosa_fuscatus,Squaterola_atthis)),Anthropoidae_lagopus)),Saxicola_quinquestriatus),Ninox_albatrus),(((Alloporus_quadrivirgata,((Arenaria_pendulinus,Scaphiopus_subniger),(Epicrates_deserti,Eschrichtius_stellio))),Osteopilus_clinatus),((Asthenodipsas_gebleri,Mochlus_daurica),(Nucifraga_sauritus,Petrocincla_maldivarum)))),Psammophis_tetrix),Ursus_rutilans),((((Agama_occitanus,((((((Ahaetulla_dives,Motacilla_tadorna),Hottentotta_taczanowskius),Coturnix_lutris),(((Bombina_cynodon,Hottentotta_quinquetaeniata),(Otocoris_classicus,Synthliboramphus_physalus)),Pterocles_fuscatus)),(Eunectes_trianguligerus,Picus_manul)),Uromastyx_torquatus)),(((Ardea_epops,Heteroscodra_molurus),Phalaropus_enhydris),(((((((((Cuon_flava,Myotis_leucotus),Plethodon_intermedia),Hydrochelidon_cavirostris),((Glareola_politus,Haliaeetus_middendorffi),Seokia_thibetanus)),((Hottentotta_perdix,Machetes_rufina),Larus_leucostomum)),Eunectes_strepera),(Phalaropus_jaspidea,Pseudorca_leucoptera)),Heteroscodra_solitaria),Terpsihone_squaterola))),(Allactaga_politus,(Capra_turtor,Tryngites_gibbosus))),Charadrius_daurica)),Cardiocranius_sinensis),Fulica_apus),Theloderma_glacialis),Terpsihone_himalayanus),(Eucratoscelus_nivicola,Rhinolophus_gallicus)),((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((Acanthoceros_aureostriata,(Apalone_ridibundus,Rosalia_atra)),(((((Bradypterus_melanuroides,Phoca_wumuzusume),((Capeila_aristotelis,Ortigometra_barbatus),Hysterocrates_hyemalis)),Enhydra_boyciana),((Gazella_linaria,Kinixys_cranwelli),Lycaenopsis_exanthematicus)),Thecla_leiosoma)),Aquila_nebrius),Lepidobatrachus_totanus),(Lobipes_aegagrus,(Plethodon_helena,Podoces_flammea))),Cypselus_unicus),Ciconia_maihensis),Colaeus_cinerea),(Euspiza_mexicana,Recurvirostra_cepediana)),Zosterops_dominus),(Carabus_peregrinus,Parabuthus_stimsoni)),Kinixys_calligaster),Spalerosophis_citrsola),(Basiliscus_rosea,(Phyllopneuste_bengalensis,Trachemys_terrestris))),(Anas_chrysaetus,Mareca_cliffordii)),Buthus_eremita),Recurvirostra_corone),Asthenodipsas_sauromates),Uromastyx_monorhis),Minipterus_flavirufa),Enhydris_indicus),((Chrysemys_subrufa,(Cygnus_eximia,(Fuligula_agama,Phrynocephalus_linaria))),Hysterocrates_albicilla)),Gambelia_aegagrus),Monticola_heliaca),(Dasypeltis_fragrans,(Odobenus_schneideri,Rhodostethia_sphenocercus))),(Chelydra_uluguruensis,((Chondropython_middendorffi,((((Cottus_chuatsi,Himantopus_melleri),(Haplopelma_tatarica,Iguana_riparia)),((Leuciscus_monoceros,sibiricus_albigula),Ninox_glacialis)),Pagophila_arizonensis)),((Hysterocrates_albertisii,Micropalama_ochropus),Pandion_vipio)))),(((Chalcides_agama,Cyclemys_maihensis),Nucifraga_acanthinura),Spermophilus_amboinensis)),((((((((Acanthosaura_haliaetus,(((((Balaenoptera_albertisii,Columba_xanthocheilus),Dipsosaurus_noctua),Laudakia_prominanus),((Nyctixalus_gebleri,Panthera_homeana),Pagophila_hendersoni)),Mabuya_pholeter)),((((Acanthoscurria_longipes,Phormictopus_tinctorius),Otis_mackloti),Balaenoptera_querquedula),(((Anthropoides_mongolica,Neolycaena_imperator),Phylloscopus_gebleri),Opheodrys_morinellus))),((Citharacanthus_classicus,Ptyodactylus_papuana),Salmo_wogura)),(((((Bombycilla_subcinctus,Netta_eximia),Coenobita_naumanni),Corvus_gecko),((Corvus_major,((Desnana_gordoni,Litoria_taczanowskius),Equus_latiscutatus)),(Laudakia_nipalensis,Lepus_acuta))),Euspiza_plathyrhychos)),(Falco_prominanus,Ptyodactylus_tentaculatum)),Aythia_caudatus),Sceloporus_nasuta),Ketupa_docilis)),Machetes_tatarica),((((((((((((((((((((Acanthoceros_scutulata,Eurynorhynchus_africanus),Vipera_pugnax),Rhesus_reticulatus),Gecarcinus_lesueurii),(Bombus_albirostris,Sitta_apus)),Nemorhaedus_alba),Monodon_stejnegeri),Osteopilus_acanthinura),(Phalaropus_aestivus,Rhabdophis_guentheri)),Falcipennis_tanganicus),(((Lamprophis_relictus,Pratincola_cocincinus),crecca_saxatilis),Odonthurus_cepediana)),Amphiuma_longicollis),Petrocincla_carnifex),Spalax_falcipennis),Eumeces_fasciata),Parabuthus_duplus),Rhamphiophis_aestivus),Marmota_solitaria),(Leuciscus_coelestinus,Pusa_corone)),(((((((Alectoris_galeatus,(((((((Aplopeltura_melanostictus,Rhinolophus_atriceps),Laudakia_quadriocellata),Varanus_caudatus),Cardiocranius_holbrooki),(Phormictopus_picta,Pyrgilauda_striatus)),Eutamias_hyemalis),Pelomedusa_torquatus)),Heteroscodra_mirabilis),Ingerophrynus_lutris),((Erpeton_completus,Nyctaalus_serpentina),Phoca_stylifer)),(((((((Eumeces_intermedia,Laudakia_ibis),Phrynocephalus_borealis),Nemachilus_javanica),Phalaropus_tricolor),Scorpio_modestus),Tetrao_horridum),Nucifraga_serricollis)),Paraphysa_meermani),Capeila_tricolor))),((Alauda_pardalis,Iguana_caesius),Scincus_elegans)),Oenanthe_picta),((Branta_mugodjaricus,Citellus_hypoleucos),Capeila_tataricus)),(Allactaga_mandarina,(Cervus_temminckii,Ophisops_scincoides))),Middendorffinaia_caelebs),Arctomys_sibilans),Scincus_tolai),Nemachilus_vastus),Circus_aegyptia),Saga_acuta),Capella_cinclus),Epicrates_monacha),(((Aphonopelma_bicoloratum,((Motacilla_garulla,Motacilla_heudei),(Nipponia_durus,Rhacophorus_dentata))),Dahurinaia_eburnea),Kinixys_cornix)),((Bradypodion_alterna,Equus_celeber),((Parabuthus_leucocephala,Pogona_atra),Philothamnus_percnopterus))),(Bradyporus_teguixin,(Enhudra_insignis,Pratincola_gebleri))),(Equus_vitticeps,Pelodiscus_aestivus)),(Dipsosaurus_cianeus,(((Gongylophis_minutus,Testudo_melonotis),Uncia_ciliatus),(Pelodytes_chrysaetos,Phylloscopus_acuta)))),((((Arenaria_hasselquistii,Otis_avosetta),((Candoia_cavirostris,Sus_carnifex),Lamprolepis_leucogaster)),Sterna_elegans),(Coenobita_apus,Eutamias_savignii))),Recurvirostra_cyanogenys),(Prunella_fasciolata,Synthliboramphus_calyptratus)),(Candoia_troglodytes,Tetraogallus_hasselquistii)),Pterocles_ruthveni),((((((Aquila_hypoleucos,Uncia_vegans),Notophthalmus_peregusna),(Capeila_decor,Ruticilla_lesueurii)),(Equus_spinifera,Fulica_fulva)),((Brachyramphus_albertisii,Camptoloma_circia),Eurynorhynchus_cinerea)),((Phalacrocorax_collaris,Plethodon_sauromates),Trionyx_macrops))),Charadrius_sp),Phrynomerus_coelestinus),Antilope_lasiopterus),Lagenorhynchus_vanellus),Hemiscorpius_coloratovillosum),Phrynosoma_scutulata),((((Archispirostreptus_ignicapillus,Leiolepis_heudei),Xenopeltis_leucocephala),(Gyps_campestris,Pandinus_arseniavi)),Coleonyx_caryocatactes)),Philacte_leucomelas),(Podoces_cinereus,Theloderma_tristis)),Sorex_bewickii),Buthacus_alpestris),Chen_salvator),Pagophila_personata),Passer_occitanus),(((Ameiva_glottis,((Cardiocranius_truncatus,Nyctaalus_cinaedus),Eubalaena_leucopsis)),(((Bufo_virgo,((Circaetus_apollo,Crotaphytus_cambridgei),(Heteroscodra_gratiosa,(Hirundo_ignicapillus,Scaphiophryne_papuana)))),(Emydura_vereda,Natriciteres_argali)),(Dryobates_carbo,Pelecanus_epops))),Limnodromus_arenarius)),(Erpeton_hosii,Myotis_rostratus)),(((((Alloporus_sauritus,Bos_collaris),Zosterops_adspersus),((((((((((((((((((((Ambystoma_iguana,Tetraogallus_relictus),Kaloula_jaculus),((Citharacanthus_saxatilis,Pterinochilus_tadorna),Coleonyx_shadini)),Paramesotriton_crassicauda),Ophisops_lasiopterus),(Lanius_cinclus,Regulus_tuberculosus)),(Moschus_glutinosus,Procellaria_hendersoni)),(Apalone_sagrei,(Iomachus_tatarica,Saxicola_lobatus))),Cuora_alpina),((((((Camptoloma_scincus,Ceratophrys_fulva),(Phelsuma_crassicauda,Polypedates_Anas)),(Limnodromus_botnica,Petrocincla_serpentina)),Pseudorca_taxispilota),Oenanthe_tarandus),Pogona_tarandus)),(Fulica_oxycephalum,Himantopus_dubia)),(Rhesus_irregularis,Tupinambus_onocrotalus)),Totanus_virgo),Eremophila_scincoides),Arctomys_aleutica),((((Anser_perdix,((((Gypaetus_bukhunensis,(Porzana_stagnalis,sibiricus_nippon)),Kassina_casualis),(Rhacophorus_stagnalis,Tadarida_relictus)),Haliaeetus_crassidens)),Tryngites_apollo),Chalcides_rufina),Buthus_americanus)),Pterocles_tanganicus),Remiz_viridescens),Mylopharyngodon_jubata),Eulabeia_pugatshuki)),(((Arctomys_vitticeps,Phrynohyas_fallax),(Cygnus_graeca,(Polypedates_pygmeus,Streptopelia_borealis))),(Lystrophis_emarginatus,Sphenops_miliaris))),Cuon_maritimus)),Eurynorhynchus_hardwickii),((Mochlus_placidus,Ptychozoon_marcianus),Selenocosmia_caninus)),(((Corallus_spilota,Testudo_czerskii),Nipponia_eximia),Elseya_carbo)),Gazella_carnifex)),(Gongylophis_vulpes,Synthliboramphus_scalaris)),(Amphiuma_grupus,Apus_jaculus)),(Colaeus_elaphus,sibiricus_heudei)),(Branta_lutris,Heteroscodra_strepera)),(Chelydra_caryocatactes,Trapelus_bimaculata)),((Acipenser_totanus,(Chettussia_ibera,Rhombomys_gallinago)),Alloporus_leuconotus)),Bombina_baibacina),(((((((Acanthoscurria_schokari,(Pyxicephalus_canus,Vanellus_hassanica)),Carabus_bonasus),Hirundo_sauromates),Plethodon_linaria),Grus_tatarica),(((Burhinus_cranwelli,Saiga_completus),(Madagascarophis_getula,Salmo_infrafrenata)),(Chelus_bobac,(Citellus_scincoides,Gongylophis_timidus)))),(((((((((Ahaetulla_mitratus,(Alauda_placidus,(Milvus_brachydactyla,(Myotis_cyanogenys,Ovis_stellio)))),Osteopilus_helena),Eumeces_mongolica),((((((((Androctonus_alterna,Aplopeltura_hyemalis),Fulica_carbo),(Hottentotta_musicus,(Monodon_septentrionalis,Trachemys_minutus))),Riparia_strepera),Procellaria_sp),Pelecanus_labiatus),(Calidris_caudolineatus,Mylopharyngodon_occitanus)),(Mareca_parahybana,Ruticilla_fuellebornii))),((((((Anolis_tadorna,Gavia_schokari),Nemorhaedus_hypoleucus),(Chelydra_sibirica,((Ethmostigmus_mongolica,Pratincola_citrsola),Felis_pusilla))),(Milvus_guttata,(Pachydactylus_celer,Trapelus_dorsalis))),((Bradypterus_maritimus,(Emberiza_ciliatus,Lamprophis_garulla)),((Leuciscus_cliffordii,Neophron_iankowskii),Polypedates_oenanthe))),Chondropython_botnica)),Fulica_dione),Emberiza_cachinans),Fuligula_calvus),Limnodromus_gigas))),Chondropython_pusilla),(((((Caiman_martensi,Meles_barbata),(Cyclemys_ampullatus,Damon_punctatus)),Heteroscodra_dennysii),(Homopholis_eburnea,((Latastia_chamaeleontinus,Phoca_porzana),Syrrhaptes_weberi))),((Chrttusia_amboinensis,Osteopilus_mackloti),Mustela_rufina))),Leptobrachium_middendorffi),(Larus_variegatus,Scincus_pulchripes)),Egretta_chuatsi),(((Chalcides_multifasciata,Phormictopus_dignus),(Latastia_rosmarus,Spalax_sauromates)),Paramesotriton_weliczkowskii)),Cuora_quadriocellata),((((Allobates_cherrug,Chalcides_crassidens),Cygnus_ibera),Ardea_stagnalis),Anser_leucostomum)),Sterna_salamandra),Gongylophis_hispida),((((((((((((((((((((((((((Abantias_taczanowskius,((Chen_jaculus,((Eublepharis_difficilis,(Limosa_glottis,Rhombomys_varius)),Eutamias_saxatilis)),Nemorhaedus_zonata)),((Butastur_minutus,Tupinambus_godlewskii),Scorpio_vanellus)),Paraphysa_monilis),Glareola_diadema),(Parnassius_atriceps,Rangifer_percnopterus)),((((((((((Ameiva_cinereus,Mochlus_adamsii),(((((((((((Bombus_moschata,Ophisops_anachoreta),Buthacus_personata),(Capra_imperator,Capreolus_pendulinus)),Dipus_erythropus),Nucifraga_apollo),Dyscophus_calamita),(Sericinus_mykiss,Vulpes_bairdi)),Latastia_garullus),(Rhynchaspis_bobac,Streptopelia_novaeangliae)),((Columba_tetrix,Enhydris_leucomystax),(Poephagus_nivalis,Pratincola_cepediana))),Crotaphytus_cyanogaster)),((Camptoloma_rufodorsata,((Hirundo_falcinellus,Polypedates_corticale),Megaptera_relictus)),((Chrysemys_uncia,Lagenorhynchus_africanus),(Gonocephalus_pachypus,Nyctixalus_dispar)))),Lobipes_canus),(Bombyx_viscivorus,Branta_ammon)),Capreolus_clarus),Bradypodion_tuberculosus),Riparia_hendricksoni),Riparia_canus),Kassina_yeltoniensis)),Seokia_arcticus),Teratolepis_rufodorsata),(Lycodon_savignii,Pterocles_scabra)),(((Brachyramphus_hypoleucus,Lutra_shadini),Chrttusia_rupestris),(Equus_terrestris,(Neolycaena_ruficollis,(Phrynomerus_epops,Trionyx_colubrinus))))),Eudramias_eremita),Argynnis_varius),Aegialites_piceus),((((((Alloporus_latiscutatus,((Ceratophrys_triangulum,Saga_castaneus),(Homopholis_verrucosus,Rhynchaspis_borealis))),((((Apodora_homeana,Haplopelma_opimus),((Cuon_botnica,Phrynosoma_laticauda),(Sus_cyanus,Tryngites_caniceps))),((((Cuon_himantopus,Rhynchophis_glottis),Eurynorhynchus_arcticus),Rangifer_thibetanus),(Margaritifera_atthis,Mustela_taxispilota))),(((((((Asthenodipsas_laticauda,Bradypodion_agama),((((Chlidonias_perdix,((((Cynops_torquatus,Theloderma_meermani),Saiga_plathyrhychos),Sitta_tetrix),Hemitheconyx_helena)),(Dafila_variegatus,Trapelus_insignis)),Fregilegus_rapax),Chrysopelea_manul)),Notophthalmus_pardalis),(((Monticola_pedo,Ovis_caucasicus),Ptychozoon_placidus),Trionyx_calyptratus)),(Buteo_heudei,Haplopelma_boa)),Homalopsis_caucasicus),Glareola_grus))),Notophthalmus_schneideri),Tursiops_getula),Perdix_bellii),Leptobrachium_ferruginea)),Gonocephalus_chrysargos),Tupinambus_zagrosensis),((Ameiva_galactonotus,Triturus_dominus),Underwoodisaurus_fasciolata)),Ziphius_cyanogaster),Butastur_coloratovillosum),Larus_chrysaetos),Hydrochelidon_bobac),Dyscophus_lividum),(Aegialifes_crucigera,Haliaetus_guttata)),Philacte_collaris),Acipenser_leucostomum),Casarca_calidris)),(((((Allactaga_fiber,(((Ambystoma_dactylisonans,Monticola_franckii),Hemitheconyx_leiosoma),(Ninox_varius,Scolopax_flavomaculatus))),(((((((Capra_filipjevi,(((Eubalaena_eximia,Falcipennis_pygmaeus),Oligodon_mutabilis),Lamprophis_pygargus)),Paramesotriton_duplus),Ciconia_monacha),(Lobipes_capra,Vanellus_diadema)),Eurynorhynchus_gordoni),((Castor_fuliginosus,Pelecanus_galeatus),Lycodon_fasciata)),Lutra_linaria)),(Minipterus_scutulata,(Notophthalmus_arvensis,Rhesus_semipalmatus))),(Pica_mitratus,Tupinambus_fissipes)),(Capella_calligaster,Spalax_mystaceus))),Hyperoodon_septentrionalis),((Cottus_godlewskii,Triturus_isabellina),Vipera_dentata)),Rhacodactylus_nigrolineatus),Polypedates_venulosa),((Anodonta_fragrans,Archispirostreptus_agama),Numenius_guentheri)),(Cardiocranius_taxispilota,Coturnix_longipennis)),Pogona_maihensis),Uroplatus_hendersoni),((((((Abantias_gallicus,(Almo_vulgaris,Eudramias_sauritus)),(Calidris_ridibundus,Philacte_ferox)),(((((Alauda_terrestris,((((Aythya_mutabilis,(((Coregonus_zagrosensis,((Eudrornias_striatus,Phylloscopus_lehmanni),(Rhacophorus_caudatus,Sceloporus_peregrinus))),Cyclagras_doriae),Phalaropus_mnemosyne)),Haliaeetus_bifasciatus),Terpsihone_gibbosus),Eublepharis_acanthinura)),Branta_atriceps),Meles_personata),Furcifer_vermiculatus),Motacilla_nigra)),Elseya_lineatus),(((Lycodon_equestris,Zosterops_hilarii),Opheodrys_crassidens),(Mesoplodon_taczanowskius,Neolycaena_bicinctores))),(Chettussia_platyrhinos,Tadarida_parreyssi))),Charadrius_salvator),Uncia_acuta),(((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((Abantias_papuana,Vipera_bairdii),Parnassius_pygargus),(((((Chelus_decorus,Vormela_stimsoni),Parabuthus_rufodorsata),Norops_subminiatus),Heteroscodra_caudatus),Lasiodora_chukar)),Anas_imperator),Sphenurus_garulla),(Gerrhosaurus_melanostictus,Phyllopneuste_scincus)),Riparia_boulengeri),Canis_guttata),Aplopeltura_apollo),(((((((((Almo_regius,Boiga_longipennis),(((((Aphonopelma_nebularia,(Ceratophrys_musculus,Trapelus_caeruleus)),Cynops_hasselquistii),Phrynomerus_atra),Vormela_piscator),Nyctixalus_picta)),((Argynnis_trigonopodus,(Athene_japonica,Pelusios_albicilla)),Phylloscopus_politus)),((Cottus_clarus,Lycodon_nigropalmatus),(Pelodiscus_politus,Sternotherus_guineti))),((Cervus_pachypus,Osteopilus_davidiana),Rhinolophus_maculatum)),(Oligodon_carbo,Saga_vitticeps)),Enhydra_getula),Tamias_coelestis),(((((Capella_mitratus,(Cyclagras_constrictor,Damon_emilia)),Thecla_dentata),Saiga_tetrax),Pleurodeles_alpinus),(Circus_homeana,Plethodon_pictus)))),Diomedea_fimbriatus),Alaus_totanus),Alauda_amboinensis),((Corallus_madagascariensis,Rhacodactylus_rudicolis),Eunectes_helvetica)),(((Aphonopelma_pugnax,Bufo_duplus),(Rhynchaspis_erythropus,Tetrao_melanostictus)),Hysterocrates_hungaricus)),Prunella_sphenocercus),Hottentotta_grunniens),(((((Burhinus_stellatum,Coenobita_ammon),Kinixys_maculata),Monodon_geniculata),((Phrynomerus_ferruginea,Rufibrenta_Bernicla),Tringa_albirostris)),Xenochrophis_clinatus)),Eunectes_borealis),Tryngites_parahybana),((((((((((Actitis_botnica,((Anser_guangxiensis,Vipera_trianguligerus),Mustela_varius)),Porzana_rudicolis),Cervus_kraepelini),((Ahaetulla_albatrus,Lamprolepis_sebae),Dasypeltis_nasicus)),(Plethodon_apus,Poephagus_buccata)),(Podoces_bewickii,Sorex_apus)),(((Anser_quinquestriatus,Oxyura_nupta),(((((((((((((((((Asthenodipsas_tristis,Rhinolophus_calligaster),(Dendrobates_govinda,Phalaropus_aureola)),Geochelone_enhydris),Nemachilus_atrigularis),Riparia_diadema),Pusa_monorhis),((((Aythia_govinda,Heteroscodra_maurus),Synthliboramphus_piscator),Phylloscopus_stellatum),(Madagascarophis_carolinensis,Sus_proteus))),Cynops_brevirostris),Euspiza_edulis),Fregilegus_lutra),(Bufo_chuatsi,Pituophis_turneri)),Podoces_bukhunensis),Rosalia_cenchria),Hydrochelidon_picta),Triturus_doctus),Nhandu_leptochelis),Rosalia_mongolica)),Cynops_alpina)),(Glareola_nippon,(Leptobrachium_hypoleucos,Melanocorypha_lividum))),Arenaria_perrotetii),(Anodonta_boyciana,(Gekko_fuscus,Pandion_cornix)))),Cuon_major),(((((((Acheron_medici,Hysterocrates_amethistina),Branta_mitratus),((((Aegialites_hungaricus,Chrttusia_dispar),Ptyodactylus_indica),(((((((((((Bradyporus_ameiva,Parnassius_sphenocercus),Coenobita_carbonaria),Saxicola_tatarica),Uroplatus_clarus),((Phrynosoma_corticale,(Scaphiophryne_oxycephalum,Vanellus_semipalmatus)),Ursus_maihensis)),Pelodytes_kopsteini),((Desnana_livia,Sturnus_caesius),Kinosternon_epops)),(Calotes_means,Cyriopagopus_semipalmatus)),Thamnophis_lutris),(Picus_epops,Vulpanser_canorus)),Castor_fluviatilis)),Physignathus_prasina)),Falcipennis_dubia),Terpsihone_heliaca),Dendrobates_nasuta),(Calotes_ladogensis,Poephagus_sibilans))),((((Acanthoceros_gratiosa,((Ambystoma_bukhunensis,((Chrysemys_musicus,Totanus_collybitus),Ethmostigmus_argentatus)),(Minipterus_enhydris,Pusa_mugodjaricus))),Androctonus_barbatus),Balaenoptera_novaeangliae),Tadarida_sauritus)),Corallus_clypeata),((((((((((((((((((((((((((Acanthogonatus_cyanus,(Canis_reticulatus,sibiricus_exanthematicus)),Rissa_celer),Cuora_azureus),Zosterops_melanoleucus),(((((((((Antaresia_caelebs,Gongylophis_livia),Eubalaena_rufus),Recurvirostra_mysticetus),Gonyosoma_montela),Eutamias_monedula),Limosa_bicinctores),Mylopharyngodon_pachypus),(Homalopsis_savignii,Pandinus_carnivorus)),Scorpio_maldivarum)),Ephibolus_madagascariensis),(((((((Alauda_turneri,Camptoloma_eulophotes),Archispirostreptus_troglodytes),Meles_eximia),Cyriopagopus_decorus),Pedostibes_cianeus),((Apus_maculatum,(((Bombyx_rubida,((Hemiscorpius_pallidus,Teratoscincus_leucoryphus),Uroplatus_emarginatus)),(Otocoris_hongkongensis,Tryngites_mnemosyne)),Mochlus_heterolepidotus)),Ingerophrynus_gigas)),(Eumeces_paganus,Eutamias_hypoleucos))),Oedura_quadriocellata),Crocodylus_multifasciata),Lyrurus_cliffordii),Eudrornias_acutus),Corallus_lopatini),(Alauda_verrucosus,(Oedura_fluviatilis,(Telescopus_korschun,Uncia_similis)))),(((((((((((Acanthosaura_acuta,((Lycaenopsis_quadrivirgata,Zosterops_papuana),Ortigometra_subcinctus)),Laudakia_avocetta),((((((((((Acanthosaura_scalaris,(Chalcides_rostratus,Rhacodactylus_constrictor)),(Pogona_rutilans,Rissa_cinerea)),(Chettussia_atriceps,((Oxyura_undulata,(Recurvirostra_daurica,Tryngites_taezanowskyi)),Podoces_sanguinolentus))),(Kinosternon_bairdi,(Lamprophis_ferox,Ninox_cynodon))),(Holaspis_virgo,Morelia_peregusna)),((((Elaphe_unicolor,Pterocles_quinquetaeniata),Uncia_sp),((Eunectes_monoceros,Procellaria_martensi),Terpsihone_diffidens)),Xenochrophis_falcinellus)),((Dendrelaphis_maldivarum,Enhudra_fuellebornii),Haplopelma_cavimanus)),Eurynorhynchus_decor),(((Aphonopelma_dentata,Coleonyx_sagrei),Lystrophis_zenobia),Rhacodactylus_canorus)),Hydrochelidon_lineatus)),((Cyclemys_iankowskii,Pelusios_drapiezii),Selenocosmia_uluguruensis)),(Emberiza_lavaretus,Teratoscincus_cyanus)),((Haliaetus_enydris,(Mylopharyngodon_pugnax,Vipera_mycterizans)),(Melanocoryhpa_ignicapillus,Trionyx_mycterizans))),Salmo_monacha),Eulabeia_carnifex),(Asthenodipsas_rupestris,Pagophila_bewickii)),(Mogera_maculata,Nemachilus_melanuroides)),((((Acipenser_ibis,Asthenodipsas_amboinensis),Columba_anatina),((((Actitis_torquatus,((Coregonus_boyciana,Nucifraga_tinnunculus),Lutra_thibetanus)),Eumeces_bewickii),Numenius_mongolica),Oenanthe_alpinus)),(((((((((Agama_crassicauda,Pyxicephalus_citreola),(Buthus_hardwickii,(Callipogon_soloensis,((Corytophanes_grupus,Fuligula_vitulina),Pica_mirabilis)))),(Buteo_situla,Siniperca_notaeus)),Cyclemys_scincoides),(Dendrobates_dentata,Nyctaalus_maurus)),Latastia_tinnunculus),(Charadrius_walti,Hyla_monilis)),Androctonus_carinata),((((Capra_grus,Triturus_taxispilota),Holodactylus_pardus),Oenanthe_cachinans),(Hyperoodon_cavirostris,Nhandu_circia)))))),Apalone_hemilasius),(Balaena_auriculatus,Lystrophis_carbonaria)),Cardiocranius_japonensis),(((Capeila_davidiana,((Chondropython_papuana,Sceloporus_cepediana),Recurvirostra_flavomaculatus)),Nerodia_tadorna),Psammophis_sagrei)),Ethmostigmus_eulophotes),Chlamydotis_fischeri),(((Actitis_pica,Gecarcinus_vitticeps),Xenophrys_taezanowskyi),((((((Dendrobates_monoceros,Nhandu_breitensteini),Eubalaena_terrestris),Gypaetus_albatrus),Numenius_maculatum),Pelodiscus_cancerides),(Pelodiscus_semipalmatus,Pleurodeles_pelagicus)))),(Buthus_parvus,((Chen_crucigera,Hydrochelidon_xanthocheilus),Salmo_sepsoides))),(Eirenis_albertisii,Falcipennis_prasina)),Phalacrocorax_veredus),((Coenobita_grossmani,(Kassina_buccata,Morelia_jaculus)),Ingerophrynus_nipalensis)),Teratolepis_nivicola)),Furcifer_corone),((Anser_fernandi,Emydura_weliczkowskii),((((Coregonus_nigrolineatus,Pleurodeles_brongersmai),Pituophis_flavolineata),((Hirundo_grunniens,Minipterus_regius),Riparia_subrufa)),Sceloporus_cristata))),(((((((((Allactaga_melanostictus,Pelodiscus_chamaeleontinus),Underwoodisaurus_alpina),(Butastur_krueperi,Rhynchaspis_jaculus)),Eunectes_americanus),(Gongylophis_erythronotus,Tadarida_buccata)),Cottus_ferrumequinum),Madagascarophis_arvensis),Tetrao_altaica),Osteopilus_kuhli)),Lampropeltis_milii),((((((((((((((((((((((((Acanthogonatus_olivacea,Euspiza_Anas),((((((((Aix_perrotetii,Hadrurus_stellatum),(Falco_armata,Pyrgilauda_rusticolus)),(Apodora_rubida,Kinixys_pygargus)),Trapelus_vertebralis),Dryobates_mnemosyne),(Dyscophus_musculus,(Moschus_leucocephala,Xenophrys_tarda))),Podoces_collectivus),(Larus_aegyptia,Salvelinus_gallinago))),Squaterola_lividum),(Allobates_tricolor,Haplopelma_ceterus)),Bombyx_blakistoni),Carabus_cherrug),Alauda_exanthematicus),Phoca_dubia),(Butastur_pusilla,Odonthurus_bedriagai)),Chrysopelea_rutila),(Dryobates_mycterizans,Pelodiscus_glacialis)),(((Chrysopelea_flava,Spalax_diadema),((Iguana_pulchripes,Salvelinus_interiorata),(((Marmota_nivicola,Saga_resinifictrix),Physignathus_maculatum),Scolopax_paradisi))),Limosa_triangulum)),Ortigometra_felderi),(Bombina_climacophora,(Himantopus_geyri,Leiurus_bewickii))),Tursiops_vitulina),Spalerosophis_serricollis),Corytophanes_durus),Vulpes_serricollis),((((((((((Allactaga_nippon,Eudramias_cygnus),Capella_taczanowskius),Phrynosoma_leucophtalmos),Amphiuma_reinwardti),Philomachus_isabellina),Antaresia_unicus),((Emydura_ichthyaetus,Laudakia_spinifera),(Hottentotta_mehelyi,(Odobenus_duplex,Vanellus_acutus)))),(Coenobita_strepera,(Larus_longipennis,Pseudemys_cavimanus))),Ortigometra_rufina),((Opheodrys_alba,Paradoxornis_coturnix),Phelsuma_stejnegeri))),((((((Aegialifes_marinus,Leiopython_lividum),Rhabdophis_geyri),Lagenorhynchus_floridana),((Alopex_viscivorus,Hyla_manul),Syrrhaptes_dexter)),Eremophila_corsac),Leiolepis_brevirostris)),(((Babycurus_helena,Pelusios_monilis),Dipus_jaspidea),Regulus_calamita)),Coleonyx_ovata),(((((((((((((((((((((((((Acanthosaura_baeri,Marmota_subrubrum),Python_uncia),Bos_melleri),((((((((((((((((((Acanthosaura_moschiferus,((Anodonta_mutabilis,(Cyriopagopus_bifasciatus,Terpsihone_wislizeni)),Scaphiophryne_avicularia)),((Allobates_albocinctus,Phrynops_leucophyllata),Querquedula_tinnunculus)),Androctonus_imperator),Pseudemys_Jankowskii),(Dyscophus_brandtii,Lagenorhynchus_collaris)),Atrophaneura_alpina),Dasypeltis_quinquetaeniata),(Micropalama_madagascariensis,Tupinambus_vanellus)),(Eublepharis_smithi,Nucifraga_marcianus)),((Lycaenopsis_maldivarum,(Megophrys_marmoratus,Varanus_onocrotalus)),Phylloscopus_scincus)),Rhabdophis_bedriagai),(Bubulcus_prominanus,((((((Chlamydosaurus_floridana,Rhacophorus_wislizeni),Gonyosoma_getula),Eunectes_africanus),(Phrynops_krueperi,Pyrrhocorax_leucostomum)),Paraphysa_valliceps),Odonthurus_schokari))),Fregilegus_gobio),((Aegypius_schokari,Sterna_korschun),Arctomys_nigra)),Ethmostigmus_novaeguineae),Eudramias_fallax),(((((((((((Bombus_heliaca,Sus_gemmicincta),Falco_sauromates),Paradoxornis_rostratus),Lobipes_sujfunensis),(Gyps_nasicus,Philothamnus_griseus)),Brachypelma_ammon),Pyxicephalus_godlewskii),Corvus_wogura),Glareola_lavaretus),Pterinochilus_temminckii),Lanius_decorus)),(((((((Aegialites_doriae,(Aythya_crassidens,Callipogon_unicus)),Gypaetus_dives),Atrophaneura_perdix),(Archispirostreptus_lopatini,Salamandra_alpina)),Sericinus_cranwelli),Lagenorhynchus_sepsoides),Cinclus_picta))),(Machetes_cyanus,((Oedura_crocodilus,Phoca_septentrionalis),Teratolepis_felderi))),(Anthropoides_chrysargos,(Felis_gigas,Hadrurus_labiatus))),(((((Alaus_schreibersi,(Arenaria_tigrinus,Rhacodactylus_solitaria)),((Casarca_casualis,(Fulica_acuta,Querquedula_caeruleus)),Megophrys_bifasciatus)),(Oenanthe_tridactylum,(Porphyrio_arvensis,Sphenurus_celeber))),Numenius_monoceros),(((((((Antaresia_longipennis,Pterocles_calvus),Lamprolepis_carbo),((Capella_sibilans,Ziphius_sauritus),Pica_chukar)),Monodon_nigrolineatus),(Passer_tataricus,Pterocles_geniculata)),Xenopeltis_teniotis),Cottus_alpina))),Lobipes_seemani),((Circaetus_perdix,Monachus_standingii),(Cygnopsis_jacksoni,((Felis_glacialis,Platalea_conicus),Ophisops_mystacinus)))),(Aegypius_australis,Spermophilus_baibacina)),Phrynosoma_erythropus),Bombyx_jaspidea),(Eryx_rubicola,Gambelia_turtur)),Ctenosaura_subruficollis),((Allobates_grus,Emydura_strepera),(Carabus_hyperboreus,Fulica_metallica))),Mergus_leucoryphus),Elaphe_buccata),Xenochrophis_auratus),Sphenurus_parvus),(((Bufo_rusticolus,(Chen_pygmeus,Mergus_ocellatus)),Terpsihone_alterna),Pelodytes_caudatus)),((((((Candoia_weliczkowskii,Chamaeleo_elaphus),Chlamydosaurus_noctua),(Corytophanes_canus,Equus_politus)),Marmota_enydris),Equus_milii),(Phelsuma_anser,sibiricus_nigrolineatus))),(Coregonus_sibiricus,Cyclagras_punctatus)),Oedura_vereda),(Latastia_madagascariensis,Tetraogallus_laevis)),((((Cypselus_calidris,(Pterinochilus_lavaretus,Varanus_hongkongensis)),Numenius_sirtalis),Telescopus_moschata),Machetes_salamandra))),Alopex_pygmaeus)),((Butastur_castaneus,((Capella_cepediana,(Nerodia_parreyssi,Rhesus_deminutus)),Seokia_armeniacus)),(Calotes_leucogaster,(Capra_marmoratus,Xenochrophis_bengalensis)))),Lamprolepis_walti),Selenocosmia_fuscus),((((((((((((((((((Abantias_wogura,(Mogera_fluviatilis,Tadarida_macularius)),(Anas_smithi,((((((Bombina_modestus,Caiman_cygnus),Lepus_fischeri),Pareas_tolai),Cyriopagopus_avocetta),Dendrobates_anser),Selenocosmia_septentrionalis))),Vormela_leucoryphus),Elaphe_deserti),(Chlamydotis_hungaricus,(Eschrichtius_notaeus,Sterna_mackloti))),Chettussia_cinereus),((Ctenotus_galericulata,(Milvus_japonensis,Telescopus_platyrhinos)),Natriciteres_variabilis)),Oenanthe_irregularis),Accipiter_tarandus),(Chrysemys_australis,((Eulabeia_virgo,Remiz_hendricksoni),Phylloscopus_corticale))),(((Almo_nebularia,Xenopeltis_vitulina),Gecarcinus_parahybana),((((Anodonta_decor,Ursus_capra),Nyroca_bedriagai),Phoca_capreolus),((((Bombina_clypeata,(Buthacus_metallica,Capreolus_lepturus)),(((Bradypodion_hendersoni,Phylloscopus_mystacinus),Chlamydosaurus_clericalis),Eutamias_africanus)),Chelodina_paradoxus),Vulpanser_acutus)))),Ameiva_ferruginea),Milvus_subrubrum),Micropalama_iankowskii),((Amphiuma_bengalensis,Kinosternon_monilis),((((Kinixys_wogura,Tamias_hypoleucos),Pseudemys_pulchripes),sibiricus_ornata),Odonthurus_ignicapillus))),(Dryobates_reticulatus,Ruticilla_tristis)),Tursiops_leucoptera),(((((((((((((((((((((Acanthoscurria_brevipes,((((((((((((((((((Agama_rosmarus,Fregilegus_taczanowskius),Coturnix_viscivorus),Phelsuma_variegatus),Chen_schrencki),(Ardea_lutris,(Brachypelma_torquatus,Columba_fuellebornii))),Eunectes_crocodilus),Aquila_deserti),((Apodora_erythrogastra,Procellaria_falcipennis),Aquila_relictus)),Tylototriton_vereda),Cottus_citreola),(Cardiocranius_mitratus,Chrysemys_avocetta)),(((Alloporus_uluguruensis,((Certhia_falcipennis,Hadogenes_breitensteini),Cypselus_ferox)),Almo_dauricus),(Bradypterus_reticulatus,Coleonyx_mirabilis))),((((((Aplopeltura_cyanogaster,Bombyx_brachydactyla),Eumeces_cyanochloris),Vulpanser_vegans),(((((((Arctomys_vipio,Rhacophorus_cyanogenys),Chelodina_himantopus),Erpeton_taczanowskius),(Buthacus_fasciata,((Calotes_vereda,Otocoris_lutris),(Parabuthus_anser,Xenopeltis_auriculatus)))),Halichoerus_carnivorus),Cyclemys_reinwardti),Mochlus_dione)),((((Bradyporus_means,((Eremophila_parvus,((((Ethmostigmus_constricticollis,Leuciscus_karelini),Lyrurus_mexicana),Pituophis_melonotis),(Phrynohyas_eremita,Thymallus_moschiferus))),Leiolepis_tarandus)),((Chlamydotis_ferrumequinum,Riparia_anser),Haplopelma_pardalis)),Tadarida_nebrius),Morelia_alpina)),Coregonus_gallicus)),Cottus_resinifictrix),Bronchocela_viridis),Dendrelaphis_dauricus),((((((((((((((((((((Agama_stellio,((Eulabeia_linaria,Tringa_taczanowskius),Oceanodroma_modestus)),Cottus_cyanochloris),((((((Bufo_plathyrhychos,((Chettussia_taeniura,Eurynorhynchus_mycterizans),(Gazella_carinata,(Iomachus_limosa,Mesoplodon_mandarina)))),((((((Buthus_nasuta,Felis_kuhli),Cyclemys_merganser),Gavia_coelestis),(Enhudra_laevis,Teratoscincus_colombianus)),Cygnus_leucopsis),Pyrrhocorax_galeatus)),Holaspis_czerskii),Vulpanser_canus),Megaloperdix_caniceps),(Middendorffinaia_situla,Upupa_cinereus))),Bradypterus_paradisi),(Rhamphiophis_atra,Tetrao_rosmarus)),((((((((((Anser_ussuriensis,Ursus_avocetta),Otocoris_pallidus),Rhynchaspis_orientalis),Xenopeltis_acanthinura),Bradyporus_mandarina),Nyctaalus_mystacinus),(((Chamaeleo_ibis,(Hirundo_occitanus,Milvus_mystaceus)),((((Chamaeleo_montela,Pterinochilus_shadini),Trapelus_leucoptera),Phylloscopus_coelestinus),Minipterus_ulikovskii)),Leiurus_kingii)),Ceratophrys_amboinensis),(Egretta_minor,(Falcipennis_cyanea,sibiricus_flavirufa))),Limnodromus_buccata)),Phrynohyas_arenarius),(Synthliboramphus_decor,Zosterops_bimaculata)),Boiga_davidiana),Caiman_fuscatus),Rhombomys_rufina),Pleurodeles_caesius),((Haplopelma_percnopterus,((Pelodiscus_japonensis,sibiricus_manul),Tadarida_hilarii)),(Mustela_solitaria,Sceloporus_fallax))),(((Bos_doriae,Clemmys_completus),Hyla_lehmanni),Neophron_percnopterus)),(((Cottus_penelope,Rhamphiophis_battersbyi),Cyclagras_taxispilota),Lepidobatrachus_novaeangliae)),Callipogon_diadema),((Bradypodion_casualis,(Grampus_dives,Sphenops_lepturus)),(Grammostola_rupestris,Spizaetus_docilis))),Monodon_hodgsoni),Anthropoides_lagopus),((((Butastur_davidiana,(Leptopelis_pygmaeus,(Nerodia_cristatellus,Oenanthe_vanellus))),Haliaetus_altaica),Ortigometra_trigonopodus),Pelusios_opimus))),Corallus_valliceps)),Tropidurus_tristis),(((((((Apodora_bellii,Panthera_gregaria),(Brachyramphus_calligaster,((((Iomachus_nyroca,Lepidobatrachus_chinensis),Osmoderma_pardalis),Pyrgilauda_rubida),Morelia_equestris))),(Latastia_hyemalis,Numenius_exanthematicus)),Spizaetus_tataricus),((Equus_africanus,Lystrophis_corticale),crecca_decorus)),Furcifer_aleutica),Platemys_chukar)),(Amphiuma_apollo,Himantopus_exanthematicus)),Bubulcus_fernandi),(((Corytophanes_microlepis,Minipterus_ochropus),Iomachus_relictus),Cyriopagopus_rosmarus)),((((Archispirostreptus_caniceps,Pusa_lehmanni),Carabus_Bernicla),Cervus_situla),(Carabus_smithii,Leptobrachium_aegagrus))),(((((((Brachypelma_aegyptia,Hydrochelidon_zagrosensis),Tetraogallus_circia),Candoia_vertebralis),Candoia_lutris),Odonthurus_zenobia),Mesoplodon_erythropus),Gonyosoma_relictus)),Melanocoryhpa_porphyrio),Neolycaena_leucostomum),(Coregonus_macqueni,Phylloscopus_corone)),((Callipogon_marmoratus,Spermophilus_graeca),Pyxicephalus_licin)),Platemys_heterolepidotus),Hysterocrates_campestris),((Anthropoides_penelope,Argynnis_vipio),Coturnix_auriculatus)),Callipogon_azureus),(Canis_sagrei,Pterinochilus_physalus)),Odonthurus_uncia),(Branta_yeltoniensis,Geochelone_ulikovskii)),Panthera_melonotis),Limosa_cyanochloris))),((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((Acanthis_glacialis,Eumeces_porzana),(Calidris_dominicus,Hirundo_cancerides)),((((((Buthacus_collaris,Mylopharyngodon_Jankowskii),Saxicola_minor),Netta_cygnoides),Thamnophis_pica),(Enhydris_adamsii,Eucratoscelus_oxycephalum)),Spizaetus_crassicauda)),(((((Aegialifes_rufodorsata,(Turdus_ulikovskii,Uncia_flavirufa)),Laudakia_longipennis),(((((((((((Anser_triangulum,Sus_aristotelis),Gallinago_arvensis),Remiz_subcinctus),(Camptoloma_bengkuluensis,Eudrornias_sebae)),Himantopus_apus),Gekko_cristatella),Teratoscincus_quinquestriatus),Monticola_oxycephalum),(Coturnix_guangxiensis,(Madagascarophis_labiatus,Plegadis_Jankowskii))),Trionyx_xanthocheilus),Rosalia_porphyrio)),((((((((((((((Atrophaneura_penelope,Pandinus_acutus),Fulica_decor),Sphenops_falcinellus),Enhudra_carnifex),Rissa_helena),Eulabeia_heterolepidotus),Scaphiopus_stellatum),Pseudemys_monoceros),Rangifer_nasicus),Basiliscus_buccata),Dendrobates_nigrolineatus),Neolycaena_ion),Charadrius_jubata),Testudo_schrencki)),(Euspiza_interiorata,Laudakia_canorus))),((((((((((((Acanthogonatus_lineatus,Chrysemys_geyri),Pandion_ignicapillus),Aythya_longipennis),Parnassius_unicus),Elseya_caesius),(Teratolepis_bengkuluensis,Uromastyx_graculus)),Lystrophis_conicus),Budytes_arcticus),Bombus_seemani),Morelia_enhydris),Alloporus_nipalensis),(Aegialifes_corone,Syrrhaptes_flavomaculatus))),(((((((((((((Aegialites_climacophora,((Nyctixalus_cancerides,Porzana_physalus),(Ophisops_ovata,Vipera_multituberculatus))),Mogera_hendersoni),Caiman_blythi),Parabuthus_albirostris),Siniperca_albicilla),Tiliqua_adspersus),Uroplatus_caudicinctus),(Gallinago_schreibersi,Spizaetus_geniculata)),(Holaspis_nivalis,Hyperoodon_zagrosensis)),Gonyosoma_dentatus),Neolycaena_truncatus),Platemys_tetrix),((((((((Allactaga_taezanowskyi,Eunectes_ferina),Leiocephalus_heterolepidotus),(Emydura_bimaculata,Telescopus_viridis)),Parabuthus_medici),(Atrophaneura_horridum,(((((Certhia_gigas,Desnana_scutulata),Neolycaena_heliaca),Macrorhamphus_constrictor),Gonyosoma_saxatilis),Natriciteres_crassidens))),Sterna_squaterola),Phrynops_dubia),Sorex_subruficollis))),(Boiga_soloensis,Phrynohyas_eulophotes)),Panthera_hyperboreus),Parabuthus_altaica),(((((((Acanthoceros_metallica,((((((((((((((((((Alloporus_capreolus,Eumeces_graeca),Ortigometra_paganus),Dafila_interiorata),Sorex_celer),Streptopelia_cygnoides),Certhia_kopsteini),(Lamprolepis_interiorata,Petrocincla_agama)),Cuora_cinclus),((((((((Anser_emarginatus,Chrttusia_vermiculatus),Totanus_auriculatus),((((((((Basiliscus_fragrans,Platemys_exanthematicus),(Holodactylus_crispus,Rhesus_wogura)),Pandinus_tetrax),(Rhacodactylus_leucostomum,Tylototriton_rudicolis)),Euspiza_castaneus),Hadrurus_deserti),Mergus_virgo),Pelodytes_calamita)),Nyctaalus_blakistoni),Emberiza_isabellina),Circus_garullus),Tetraogallus_peregusna),(Sternotherus_squaterola,Vipera_bedriagai))),((Asthenodipsas_eximia,Xenophrys_obsoleta),Hydrosaurus_reticulatus)),Tadarida_caeruleus),((Anthropoidae_docilis,((Buteo_fuscus,(Ingerophrynus_femoralis,Podoces_albigula)),Vulpes_nivalis)),(((Chlamydotis_adamsii,Lepidobatrachus_hyperboreus),Circaetus_pardalis),Ciconia_rostratus))),Phrynomerus_enydris),Hirundo_tinctorius),(Pyxicephalus_schrencki,Strepsilas_taxispilota)),Haplopelma_guentheri),(Apalone_cavirostris,(Philacte_rudicolis,Spizaetus_infrafrenata))),Cyclagras_elaphus)),((((Alcedo_bicoloratum,Rissa_castaneus),(Dendrelaphis_bicinctores,Halichoerus_cancerides)),Syrrhaptes_rosea),(Ceratophrys_meles,(Dyscophus_boyciana,Sceloporus_lineatus)))),Crotaphytus_walti),Haplopelma_platyrhinos),((Cyclemys_erythrogastra,(((Net_caesius,Oligodon_latiscutatus),Odobenus_leiosoma),Rhynchaspis_tadorna)),Diomedea_doriae)),Himantopus_triangulum),Actitis_exquisita)),Rhinolophus_mirabilis),Bubulcus_ferrumequinum),Balaenoptera_galericulata),(((Canis_decor,Crotaphytus_paradoxus),Podoces_mysticetus),Dendrelaphis_boulengeri)),Xenopeltis_arvensis),Micropalama_bairdii),((((((Agama_reticulatus,Hadogenes_piceus),Thecla_holbrooki),Spalerosophis_collaris),((Alloporus_longicollis,((Hyperoodon_dactylisonans,Spalax_fiber),Moschus_vermiculatus)),Mergus_perdix)),Cuon_fernandi),Perdix_korschun)),(((Ciconia_zenobia,Poephagus_papuana),Pratincola_tigrinus),Lagenorhynchus_flavescens)),(((Acanthosaura_vereda,(Coleonyx_marcianus,(Crocodylus_korschun,Terpsihone_iankowskii))),Pterocles_smaragdina),Cinclus_avosetta)),Nucifraga_grossmani),(((((((((Ctenotus_caerulea,Oceanodroma_atra),Pelodiscus_smaragdina),crecca_meermani),(Erpeton_crassicauda,Ortigometra_mycterizans)),Madagascarophis_corticale),Lepus_dubia),Rhynchaspis_salvator),Pelodiscus_clypeata),Leiocephalus_Bernicla)),(((((((((((((Aegialites_sibirica,(Ketupa_corticale,Neophron_mongolica)),Lepidobatrachus_tarda),((((Chrysemys_hasselquistii,(Falco_tinnunculus,((Querquedula_constrictor,Scaphiopus_fuliginosus),Querquedula_nivalis))),Myotis_indica),Tamias_cenchria),Haliaeetus_gregarius)),Cottus_heterolepidotus),Arctomys_korschun),(Bombycilla_fragrans,Ophisops_himantopus)),(Platemys_savignii,Tryngites_coelestis)),(Enhydris_armeniacus,Rhabdophis_fischeri)),((Budytes_cocincinus,Citharacanthus_himalayanus),((((Diomedea_mexicanum,(Gekko_emarginatus,Mergus_sepsoides)),Euspiza_rubida),Plegadis_flavescens),crecca_medirostris))),Cinclus_bengalensis),Odonthurus_seemani),((((((((Anser_zenobia,(((Chen_xanthocheilus,(Hemiscorpius_filipjevi,Uncia_tetrix)),Pelomedusa_troglodytes),Seokia_paradoxus)),Lystrophis_galactonotus),Cypselus_ampullatus),Physignathus_karelini),Holodactylus_capra),((Ceratophrys_teniotis,((Ethmostigmus_personata,((Limosa_tinctorius,Mabuya_trigonopodus),Paramesotriton_helena)),Lagenorhynchus_ichthyaetus)),Sternotherus_flavirufa)),Panthera_hispida),(Capreolus_emilia,Castor_completus))),Cyclemys_avocetta)),Sceloporus_epops),(Alaus_tentaculatum,Notophthalmus_alba)),Monticola_albertisii),Tropidurus_salvator),Colaeus_piceus),Bradyporus_tarandus),(Burhinus_blythi,Plethodon_pachypus)),Dipus_armata),Damon_epops),Margaritifera_ridibundus),Aegialifes_grus),Paramesotriton_dendrophila),(((((((((((((((((((Acipenser_chrysargos,Laudakia_edulis),Spalerosophis_melanoleucus),(((Actitis_completus,(((Athene_comicus,Siniperca_bengalensis),((Ctenotus_musculus,Rhynchophis_ceterus),Thymallus_pardalis)),Cardiocranius_turneri)),Chelodina_martensi),Gyps_undulata)),((Aquila_tigris,Osmoderma_rubida),Scaphiophryne_dauricus)),((Aquila_ferina,(Bombycilla_flavomaculatus,Gongylophis_perrotetii)),Tadorna_stylifer)),(((Leuciscus_pardalis,((Litoria_quadrivirgata,Rhacophorus_gregaria),Rhynchaspis_ignicapillus)),Notophthalmus_docilis),Spalerosophis_holbrooki)),(Emberiza_pulchripes,(Pagophila_indica,Saga_anachoreta))),(Salamandra_classicus,Scaphiophryne_ampullatus)),Petrocincla_pachypus),(Scaphiopus_hendersoni,Syrrhaptes_lutra)),Hyla_canagica),(Homalopsis_bifasciatus,Tringa_tolai)),Gecarcinus_apus),Rhynchophis_striatus),((((((((((((Amphiuma_godlewskii,(Pandinus_jaculus,Upupa_colombianus)),Salmo_leucotus),(((Argynnis_madagascariensis,Teratolepis_subcinctus),Budytes_hilarii),Capreolus_nigropalmatus)),Balaena_kuhli),Diomedea_brevirostris),Chamaeleo_caudolineatus),Archispirostreptus_caudata),Scorpio_completus),Rufibrenta_peregrinus),Certhia_subcinctus),Saiga_licin),Holodactylus_stagnalis)),Tropidurus_purpurascens),((((((((((Aix_fasciolata,(Ardea_gemmicincta,Aythya_duplex)),Grampus_hendricksoni),Megophrys_prominanus),Siniperca_imperator),crecca_erythrogastra),Passer_fragrans),Boa_nigrolineatus),(Diomedea_melleri,Limnaeus_piscator)),((((Bradypodion_alpina,Rhynchophis_coloratovillosum),Certhia_adspersus),Hydrosaurus_serricollis),(Certhia_falcinellus,Philothamnus_ibera))),(((Alauda_alcinous,(Gyps_subrubrum,Lasiodora_pelagicus)),Ambystoma_dubius),Iguana_scripta))),Alloporus_placidus),((((Apalone_dives,Phoca_exquisita),Apodora_nasicus),Dyscophus_smaragdina),Norops_longicaudata))),Chrttusia_hosii),((Alopex_dolosus,Tetrao_cyanogaster),((Colaeus_montela,Lepidobatrachus_interiorata),Lagenorhynchus_imperator))),(Actitis_not,Certhia_peregrinus)),Mochlus_proteus),Chlamydosaurus_cinclus),((((((((((((Aegypius_fuscus,(((((((((((Elaphe_insignis,Erpeton_septentrionalis),Perdix_scalaris),Sceloporus_gregarius),((Falco_fasciolata,Perdix_platycephala),Kassina_weberi)),Salvelinus_hodgsoni),Melanocoryhpa_celer),((((Falcipennis_epops,Paramesotriton_mykiss),Phasianus_nigropalmatus),Saga_longicollis),(Neolycaena_proteus,(Otis_lividum,Sus_sepsoides)))),Rhinolophus_squamatus),(Lycodon_eulophotes,Siniperca_flavirufa)),((Hysterocrates_flammea,Porphyrio_parahybana),(Leiopython_taxispilota,Nyroca_rufodorsata))),Rhamphiophis_scripta)),(((Camptoloma_cinereus,(Corytophanes_reticulatus,Hadrurus_perdix)),Norops_dahurica),Fuligula_leucophyllata)),Pleurodeles_manul),Nemachilus_glottis),(Chondropython_tataricus,Grammostola_novaeangliae)),((((Allactaga_ignicapillus,(Antaresia_adamsii,Aphonopelma_stimsoni)),(Equus_decorus,Megophrys_auriculatus)),(((((((Alopex_hipposideros,(Alopex_valliceps,Lepidobatrachus_botnica)),(Dasypeltis_dexter,Scorpio_nebularia)),(Larus_leucopsis,Pituophis_geniculata)),Platemys_mnemosyne),Ruticilla_unicolor),(Bradyporus_taeniura,Kaloula_horridum)),(Bombycilla_barbatus,Tadorna_avosetta))),((Balaenoptera_caniceps,(Enhudra_weliczkowskii,Grampus_altaica)),Minipterus_venulosa))),Sternotherus_Bernicla),Columba_docilis),Corallus_guangxiensis),Oligodon_cinereus),((Cypselus_cinclus,Hemitheconyx_alcinous),Spalerosophis_lobatus)),Oedura_unicus)),((Capella_strepera,Ortigometra_hendricksoni),Rhabdophis_colombianus)),Kinixys_rubida),Chelus_carolinensis),Paramesotriton_lesueurii),Petrocincla_major),(((((((((((Balaena_hardwickii,(Nyctaalus_scripta,Phrynosoma_serricollis)),Himantopus_labiatus),Hyla_taczanowskius),Hydrochelidon_maldivarum),Phrynosoma_hemionus),(Brachypelma_viscivorus,Capra_albatrus)),Pelodiscus_rubida),(Boiga_dives,Oligodon_marcianus)),Podoces_krueperi),((Eryx_laevis,Thecla_arenarius),Phrynomerus_cianeus)),Lagenorhynchus_viscivorus)),(Porphyrio_auratus,Tursiops_fuscus)),Rhesus_rhymnus),Testudo_pulcher),Ruticilla_pallidus),(((((Bubulcus_maldivarum,Physignathus_cyanochloris),Coleonyx_auriculatus),Mabuya_americanus),Natriciteres_fiber),(Cyclagras_saiga,Megaptera_novaeangliae))),(((((Alauda_cherrug,(Hydrochelidon_cambridgei,Thecla_crocodilus)),(Cottus_merganser,(Kinixys_timidus,(Mochlus_franckii,(((Oligodon_canorus,Tryngites_auratus),Regulus_rupestris),Osteopilus_bairdi))))),Camptoloma_falcinellus),Falco_papuana),(Dipsosaurus_middendorffi,(Odobenus_seemani,Rhamphiophis_punctatus)))),(Aegialifes_hyemalis,Hirundo_iankowskii)),Pogona_compactus),Philomachus_erythropus),Fulica_cinaedus),Rhesus_heudei),(((((((Anolis_molurus,(Gonocephalus_zagrosensis,Tylototriton_grandis)),(((Argynnis_valliceps,Passer_himantopus),Dryobates_fuscatus),Uncia_ibera)),Ptychozoon_hasselquistii),Phylloscopus_armeniacus),Haliaeetus_holbrooki),Athene_caudolineatus),((Aphonopelma_stejnegeri,(Enhydris_enydris,(Phrynomerus_reinwardti,Rhodostethia_pallasii))),Lamprolepis_filipjevi))),(((Athene_rubida,Atrophaneura_lobatus),Lycaenopsis_equestris),Hyla_taxispilota)),(Oceanodroma_castus,Rhamphiophis_trigonopodus)),(Dipus_radiata,Sphenops_cavimanus)),Corytophanes_tataricus),((Acanthoceros_vitticeps,(Himantopus_flavolineata,Teratolepis_canorus)),(Capella_politus,Chelus_sirtalis))),((((Cygnopsis_tadorna,Tursiops_gibbosus),Eryx_cygnus),Poephagus_mykiss),(Poephagus_calyptratus,Totanus_caeruleus))),(Damon_guttata,Parnassius_acanthinura)),Archispirostreptus_montela),(((((Allactaga_nelsonii,Cyclagras_trigonopodus),Pyrgilauda_ornata),((Elseya_ibera,(((Furcifer_smithi,Pterinochilus_teguixin),Milvus_multituberculatus),Strepsilas_erythronotus)),Salvelinus_deminutus)),Paramesotriton_ochropus),Myotis_geyri)),Lepus_vertebralis),Lagenorhynchus_leucogaster),(((Aegialites_saxatilis,Pica_middendorffi),Ketupa_edulis),(((Chalcides_barroni,Cottus_middendorffi),Grammostola_longicollis),Pseudemys_canorus))),Dyscophus_murinus),Limnodromus_castus),Halichoerus_alpestris),(Gazella_americanus,Poephagus_arvensis)),(Eudramias_pygmeus,Vormela_plumifrons)),(Chelydra_durus,Eubalaena_rufinus)),Mylopharyngodon_stagnalis),(Nemachilus_schneideri,Osteopilus_fulva)),Rhacophorus_tigris),(((((((((((((((((((((((((Acanthoceros_quinquestriatus,((((((Buthus_cocincinus,(((Oedura_hemionus,Rhynchophis_pulchra),Pandinus_hassanica),Uromastyx_cristatellus)),Cynops_cinereus),Capra_graeca),Glareola_cachinans),Chamaeleo_kazanakowi),(((Chrttusia_timidus,Machetes_barroni),Perdix_pulcher),Ortigometra_catenifer))),Buthacus_gratiosa),(((((((((((((((Acanthoceros_zonata,Underwoodisaurus_mandarina),((Androctonus_gallinago,(Euspiza_hassanica,Onychodactylus_mandarina)),(Paramesotriton_dominicus,Ziphius_hemionus))),Squaterola_hasselquistii),((Opheodrys_orientalis,Passer_molurus),Streptopelia_linaria)),(Hydrosaurus_rubida,Telescopus_durus)),((Lycodon_totanus,Saxicola_hemilasius),Rhynchophis_punctatus)),Anthropoides_heterolepidotus),Pagophila_bairdi),((((Bombina_paradoxus,Tetraogallus_subniger),Laudakia_campestris),Cuon_latiscutatus),Pelodytes_sudanensis)),Tupinambus_clericalis),Scorpio_salei),Coregonus_nigriceps),(((Alectoris_walti,((Gypaetus_calyptratus,(Heteroscodra_imperator,Tryngites_cristatellus)),Ketupa_subcinctus)),Paradoxornis_anatina),Norops_conicus)),Ctenosaura_leucogaster),(((((((((((Acheron_lutra,Kaloula_wumuzusume),(Ahaetulla_pugatshuki,Rhacodactylus_erythrogastra)),Certhia_hemilasius),(((Avicularia_ampullatus,Poephagus_cinclus),Bombycilla_salvator),Salmo_truncatus)),(Alauda_interpres,((Aphonopelma_cyanogaster,Pyrgilauda_canagica),Candoia_cherrug))),(Scaphiopus_aegyptia,Thymallus_leucopsis)),(Archispirostreptus_rosmarus,(Rissa_vegans,Ursus_bifasciatus))),Hadogenes_unicus),Eublepharis_fulvus),Babycurus_trigonopodus),((((Allobates_cinclus,Rhabdophis_horridum),Middendorffinaia_cristatus),Ceratophrys_castus),Babycurus_melanostictus)))),(((((((((((((((((((((((((Acanthogonatus_dauricus,((((Aegialites_ulikovskii,Furcifer_exquisita),Telescopus_lavaretus),Nemachilus_alterna),((((((Apalone_calvus,(Bradyporus_taezanowskyi,Caiman_getula)),Homalopsis_hasselquistii),Lasiodora_vittatus),Phormictopus_arcticus),Haliaeetus_cyanus),Onychodactylus_nivicola))),((((((((((((((Aegialifes_caryocatactes,Emberiza_vulpes),Micropalama_piscator),(Caiman_musicus,(Chlamydotis_corone,Scaphiophryne_percnopterus))),((Gekko_jaculus,Monodon_epops),Tadarida_interpres)),(((((Aegialifes_femoralis,((((Gavia_ceterus,Sorex_leiosoma),(Geochelone_major,Hyla_chamaeleontinus)),Squaterola_hendersoni),Tiliqua_metallica)),Hyla_vulgaris),Athene_subrubrum),Grammostola_uluguruensis),Osteopilus_monachus)),((((Allobates_zagrosensis,Aquila_ibis),(Cygnus_avocetta,Pyrrhocorax_hongkongensis)),Physignathus_fusca),(Sericinus_kraepelini,Ziphius_lutra))),Bombyx_cherrug),Rhacophorus_climacophora),Haliaeetus_borealis),((Chamaeleo_davidiana,(((Cyclemys_isabellina,Pelecanus_acuta),Nyctaalus_pallidus),Nucifraga_pardalis)),Totanus_montela)),(Cuon_subcinctus,(Dyscophus_labiatus,(Gerrhosaurus_lutra,Uromastyx_intermedia)))),Eremophila_heliaca),Athene_papuana),Salvelinus_pugatshuki)),(((((((Aegypius_nasicus,((Laudakia_calamita,Rhombomys_blakistoni),Seokia_guttata)),Milvus_ion),Falco_lutra),Lanius_clericalis),((((((((Butastur_means,((Gavia_multituberculatus,Nemorhaedus_reticulatus),Holaspis_diadema)),Tryngites_lopatini),(Holodactylus_dulkeitiana,Micropalama_leucomelas)),(Psammophis_caelebs,Remiz_metallica)),Falco_aureostriata),Polypedates_platyrhinos),Cuculus_intermedia),(Plethodon_querquedula,Sorex_stagnalis))),Clemmys_brongersmai),(Circus_caryocatactes,Pyrgilauda_bairdi))),Ambystoma_leiosoma),Atrophaneura_scripta),Androctonus_insignis),Norops_linaria),(Madagascarophis_riparia,Rissa_hispida)),((Alcedo_capra,((Mergus_ferrumequinum,Tamias_atthis),Sus_caucasicus)),Pterinochilus_saxatilis)),(Ameiva_pardalis,Candoia_standingii)),Alloporus_opimus),Coleonyx_walti),Uroplatus_rubicola),Philomachus_acuta),(Arenaria_cancerides,((Circaetus_coelestis,((Corallus_melanuroides,((Natriciteres_squaterola,Vulpanser_rufus),Otocoris_diadema)),Pelusios_tinnunculus)),Terpsihone_edulis))),(Damon_coelestis,Paraphysa_wislizeni)),Diomedea_davidiana),Dahurinaia_calidris),((((((((Aythia_musicus,Bombyx_fimbriatus),(Chrysemys_hypomelus,Corallus_pulchra)),Totanus_serpentina),crecca_riparia),Perdix_karelini),Tadorna_percnopterus),Pagophila_bonasus),Dipsosaurus_himantopus)),Cuora_pugatshuki),((Ambystoma_obsoleta,(Argynnis_crocodilus,(Melanocoryhpa_pholeter,Platalea_salei))),Emydura_musculus)),(((((((((((((((((((((((((((((Acanthogonatus_hongkongensis,(Cynops_heudei,Dryobates_cristata)),Micropalama_reticulatus),Ovis_atriceps),Nemorhaedus_cinereus),Odobenus_insignis),Saiga_ovata),Thecla_ceterus),(Buteo_yeltoniensis,Calotes_perrotetii)),Netta_caesius),Coleonyx_iankowskii),(Aplopeltura_dulkeitiana,(Leiolepis_caudicinctus,Philacte_ochropus))),((Anthropoidae_mandarina,(((((((((Aquila_perrotetii,(Megophrys_caniceps,Phylloscopus_parvus)),Porphyrio_ammon),Salamandra_gebleri),Porphyrio_belliana),(Cuon_chinensis,Phalaropus_bengkuluensis)),(((Buthus_dispar,Gerrhosaurus_gallinago),Eurynorhynchus_caniceps),Certhia_hasselquistii)),(Epipedobates_helena,Lepidobatrachus_tolai)),(Basiliscus_smithi,Nemorhaedus_acanthinura)),(Plethodon_caesius,Seokia_tristis))),Phoca_angustirostris)),Anthropoidae_quinquetaeniata),Amphiuma_perrotetii),Dipus_dispar),Pelecanus_govinda),((Chelydra_vertebralis,Phasianus_jacksoni),Gongylophis_helvetica)),((((((((((((Almo_clypeata,Norops_sibiricus),(Archispirostreptus_vitticeps,((((((Branta_citrsola,(Eubalaena_geyri,Tetrao_moschata)),Camptoloma_viridescens),(Eulabeia_isabellina,Synthliboramphus_krueperi)),((Chlamydotis_vitulina,Fuligula_albopillosum),Gonyosoma_australis)),(Chelydra_trigonopodus,Ruticilla_australis)),((((Canis_cyanus,(Coregonus_fuliginosus,((Dahurinaia_cianeus,Macrorhamphus_gecko),Spalax_hilarii))),(Mabuya_krueperi,Pratincola_ovata)),Citharacanthus_africanus),Colaeus_carinata)))),Prunella_caryocatactes),Pseudorca_angustirostris),Rhacophorus_lutris),(Bombyx_climacophora,Remiz_bimaculata)),Ciconia_diadema),Xenophrys_javanica),Sphenops_timidus),((Capra_tataricus,(Chlamydosaurus_marcianus,(Eulabeia_peregusna,Myotis_sarasinorum))),Pyrgilauda_cepediana)),Norops_leucoptera),(Pareas_anatina,Rhamphiophis_celeber))),Mabuya_prasina),((Aplopeltura_angustirostris,(Mustela_cranwelli,Saiga_auratus)),Xenochrophis_troglodytes)),(((Aphonopelma_catenifer,(Ninox_sibiricus,Pagophila_taezanowskyi)),Scolopendra_terrestris),Cuora_fuliginosus)),(Acanthosaura_clarus,Plegadis_calligaster)),Platemys_mystacinus),Castor_cornix),Trachemys_ridibundus),((Athene_rufinus,Cardiocranius_placidus),Epicrates_smaragdina)),Zosterops_brevirostris),Machetes_moschiferus),Netta_nebularia)),((((((((((((((((((((Aegialites_caudatus,Chlamydotis_triangulum),(((((Alectoris_graculus,(Corvus_coelestis,Notophthalmus_lopatini)),((Crocodylus_ochropus,(Gecarcinus_bonasus,Uroplatus_zenobia)),Eunectes_tinnunculus)),(Kinixys_ruthveni,(Paramesotriton_boa,Sorex_tigrinus))),Perdix_stellatum),((((((((((Alloporus_plumifrons,(Capeila_glutinosus,Capeila_subruficollis)),Petrocincla_marmoratus),(((Cinclus_maurus,Morelia_scincoides),(Pedostibes_leucogaster,Rosalia_smithi)),Holaspis_chrysaetus)),Strepsilas_interiorata),Phelsuma_emarginatus),((Anodonta_imperator,Leuciscus_aureostriata),Rhacophorus_Bernicla)),Myotis_sieboldii),Pyrgilauda_difficilis),Chelus_tenuirostris),Kinosternon_fischeri))),Phoca_cepediana),(((((((((Alloporus_lagopus,(Buteo_aleutica,Lystrophis_smithii)),Morelia_olivacea),(Aythya_communis,Eunectes_medici)),(Cuon_hipposideros,Eucratoscelus_musculus)),Hadrurus_taeniura),Ceratophrys_chrysargos),Eutamias_scincoides),Coenobita_leucoptera),Mogera_hyperboreus)),Gazella_exquisita),Bos_argentatus),Tadorna_hosii),Amphiuma_carnifex),(Boiga_colchicus,Paramesotriton_indica)),(Carabus_multifasciata,Tetraogallus_percnopterus)),((Platemys_brevipes,Testudo_gregaria),Siniperca_perrotetii)),((((((((((Anser_chrysaetos,Falcipennis_mirabilis),((((Certhia_dentatus,Equus_meles),Limosa_solitaria),Kassina_climacophora),(((Desnana_perrotetii,Oligodon_cristatellus),Trionyx_cavimanus),((Mylopharyngodon_percnopterus,Pandinus_coelestinus),Scorpio_kingii)))),Eschrichtius_mehelyi),Ptychozoon_vulgaris),Coenobita_femoralis),((Gonocephalus_dorsalis,Psalmopoeus_macularius),Middendorffinaia_bobac)),Chondropython_nigriceps),Hysterocrates_boschas),Ephibolus_septentrionalis),Leuciscus_pyromelana)),(((((Balaena_ceterus,Varanus_moschiferus),(Ctenosaura_sibilans,Saxicola_marcianus)),((((Brachypelma_capra,Tropidurus_rufodorsata),(Eubalaena_savignii,Rhynchophis_cepediana)),Strepsilas_melonotis),Sterna_aestivus)),(Eschrichtius_tatarica,Tamias_atrigularis)),(Ctenosaura_leschenaultii,Ptyodactylus_corsac))),((((((((((Ahaetulla_czerskii,(Dendrelaphis_leiosoma,(Plegadis_dahurica,Ptychozoon_ameiva))),Anthropoides_dulkeitiana),(Phalacrocorax_erythrogastra,Rhodostethia_erythrogastra)),Rosalia_mykiss),Rissa_aceras),Grus_mlokosiewiczi),Nemorhaedus_coelestinus),((((Ardea_caudicinctus,Bradypterus_wogura),Dasypeltis_ulikovskii),Eubalaena_korschun),Trapelus_cingulata)),Vulpanser_monorhis),Elseya_dolosus)),(Elaphe_hendersoni,Remiz_xanthocheilus)),Nyroca_sudanensis),Alectoris_albirostris),Megaptera_agama),(Aix_leucocephala,Phormictopus_oenanthe)),(Ninox_molurus,Odonthurus_porphyrio))),Leptopelis_latiscutatus),(Chrysopelea_ammon,Damon_papuana))),Rhynchaspis_microlepis),((Gonyosoma_septentrionalis,Notophthalmus_glaucescens),Rhombomys_squaterola)),Rhynchaspis_crispus),(((Alcedo_opimus,Kinixys_oenanthe),Callipogon_krueperi),Picus_leporosum)),Rhinolophus_ocellatus),(Falcipennis_hyperboreus,Gonyosoma_tadorna)),Milvus_circia),Phylloscopus_regius),Eutamias_ibera),Tupinambus_quinquetaeniata),Cyclagras_glaucescens),Epicrates_carnivorus),(((Antilope_varius,Brachyramphus_anser),(Ovis_constrictor,Paramesotriton_grandis)),(Bradypterus_tarandus,Tringa_marmorata))),(((((((Chamaeleo_corone,Rhacodactylus_hardwickii),(Pelecanus_stimsoni,Xenochrophis_macularius)),Lampropeltis_homeana),(Leuciscus_eximia,Zosterops_cristatellus)),Chlamydosaurus_sauritus),Phalaropus_cristatella),Hyla_dendrophila)),Iomachus_canagica),Terpsihone_fuliginosus),(((Allobates_rhymnus,((Eumeces_asperum,Iguana_durus),Paradoxornis_sp)),(((((((((Aplopeltura_scripta,Leiolepis_cristatus),Aythia_paganus),(Bubulcus_gregarius,(Cynops_kurilensis,Furcifer_maculatum))),Corytophanes_bellii),(((Calidris_ibera,(Circaetus_peregrinus,Platemys_aegagrus)),Eutamias_hypomelus),Gallinago_femoralis)),((Athene_wogura,Coturnix_stellatum),Gecarcinus_kazanakowi)),Synthliboramphus_moschata),(Boa_penelope,Micropalama_prasina)),Ziphius_tetrix)),(Mareca_eburnea,Pleurodeles_infrafrenata))),(((Cuora_leucocephala,Parus_davidiana),Rosalia_hyemalis),Haliaetus_reticulatus)),((((((((((((((((((((((((((((((((((((((Alaus_mugodjaricus,Oedura_tatarica),Gonyosoma_terrestris),Anolis_canagica),(Furcifer_iguana,Phasianus_totanus)),(Chelydra_javanica,Leiopython_brongersmai)),(((Ciconia_mutabilis,Eunectes_salvator),(Nemorhaedus_morinellus,Pachydactylus_maritimus)),(Pandion_venulosa,Petrocincla_ferruginea))),Onychodactylus_krueperi),(Carabus_leporosum,Rhesus_alba)),Chalcides_zagrosensis),((Middendorffinaia_coturnix,Vulpanser_porphyrio),Sorex_dennysii)),Alcedo_fernandi),Pseudorca_wislizeni),Alopex_perdix),Kassina_lehmanni),Chlidonias_erythrogastra),((Haliaeetus_mitratus,Pseudorca_anser),Limnaeus_fernandi)),Melanocorypha_melleri),Rhacophorus_medici),(Ciconia_edulis,Phalaropus_celeber)),Canis_flavigularis),Rhombomys_garulla),(Aplopeltura_catenifer,Limnaeus_alterna)),(Cyclemys_thibetanus,Nerodia_unicolor)),Vipera_subniger),((((Alcedo_rusticolus,Parabuthus_atthis),Pareas_atra),((((Bombina_caelebs,Xenopeltis_parreyssi),Net_diffidens),Corvus_trianguligerus),Scaphiopus_avocetta)),Bombyx_pardus)),Sitta_conicus),Phylloscopus_avicularia),(Allactaga_ibera,Moschus_obsoleta)),Kassina_lineatus),((((((((Brachypelma_tadorna,Ctenosaura_pulchripes),Elseya_siebenrocki),(((Cynops_gregaria,(Dendrelaphis_hendricksoni,Tupinambus_cinerea)),Sterna_deremensis),Geochelone_varius)),(Diomedea_marmorata,Egretta_hungaricus)),Carabus_rupestris),Heteroscodra_salvator),Oligodon_cenchria),Megaloperdix_jaculus)),(Cygnopsis_longipennis,Saxicola_cristatus)),Coenobita_gebleri),Allobates_breitensteini),Epicrates_dentatus),Ketupa_fimbriatus),Pica_wogura),(Nipponia_temminckii,Uroplatus_nigropalmatus)),Sturnus_mirabilis)),Capella_haliaetus),(Crotaphytus_barroni,Pogona_longicaudata))),(((((Acanthoscurria_lesueurii,(((((((((((Acanthoscurria_leucocephala,Pagophila_bobac),Vipera_nigra),Boa_minor),Corvus_cristatellus),((Coturnix_subcinctus,Paradoxornis_quinquetaeniata),Xenophrys_kurilensis)),(Cynops_coelestis,crecca_fasciata)),Larus_fasciolata),(Carabus_musculus,Mogera_lobatus)),Pelodytes_nippon),(((((((((((Chlamydotis_zagrosensis,(Vulpes_gratiosa,Xenopeltis_lasiopterus)),Opheodrys_eximia),Moschus_boa),Passer_caninus),Eubalaena_cinclus),(Regulus_heudei,(Spermophilus_tigris,Xenopeltis_hemilasius))),(Ethmostigmus_laticauda,Tupinambus_eximia)),Pandion_lopatini),Trachemys_monacha),(Falcipennis_leucocephala,Himantopus_fusca)),Phrynosoma_macularius)),((Alcedo_mykiss,(((Bufo_chukar,((Gavia_grandis,Gongylophis_eburnea),Holodactylus_diffidens)),(Elseya_davidiana,Regulus_kurilensis)),Chondropython_mycterizans)),Spalax_leporosum))),(Arenaria_cocincinus,(((Calotes_quadriocellata,Leiocephalus_occitanus),(Holodactylus_carnifex,Melanocorypha_physalus)),Haliaeetus_versicolor))),(Bombyx_rosea,Hydrosaurus_coelestinus)),(((((Apalone_capra,Chrysemys_pachypus),Damon_horridum),Cottus_albertisii),Sus_garmani),Crotaphytus_pyromelana)),((((Butastur_fimbriatus,((Chlidonias_salvator,Phrynomerus_trianguligerus),((Lagenorhynchus_pendulinus,Tetraogallus_rubicola),Pseudemys_soloensis))),Porphyrio_alpinus),(Dryobates_clinatus,Odobenus_dolosus)),Pusa_fasciolata))),((Anthropoidae_rosmarus,((Babycurus_alba,Homopholis_maihensis),Phrynomerus_dentatus)),Lasiodora_tetrax)),Oceanodroma_metallica),((((((Aegypius_moschata,Porzana_bairdii),Heteroscodra_nasicus),Pelusios_ornata),(((((Ardea_ciliatus,(Mylopharyngodon_dubia,Phrynosoma_leporosum)),((Chlidonias_keyzerlingii,Coturnix_nippon),(((Dryobates_kazanakowi,(Lanius_amboinensis,Pelodiscus_acutus)),Phalacrocorax_comicus),Leuciscus_plathyrhychos))),Otis_salvator),Platemys_marmoratus),Psalmopoeus_tarda)),(Anas_avocetta,Dasypeltis_paganus)),Ephibolus_maihensis)),Python_querquedula),(Androctonus_cepediana,Lamprophis_schreibersi)),(((((Dipsosaurus_minutus,Pelodytes_pedo),Glareola_tinnunculus),(Eschrichtius_collybitus,(Laudakia_glaucescens,Sterna_galeatus))),Rangifer_scincus),Lagenorhynchus_teniotis)),Mogera_chuatsi),Paradoxornis_crocodilus),(((Chalcides_vertebralis,Xenopeltis_saxatilis),(Cyriopagopus_medici,Enhudra_jaculus)),Sturnus_angustirostris)),Rangifer_bellii),((((((((Acanthosaura_bellii,Pyxicephalus_mykiss),Tadarida_interiorata),Anthropoides_chuatsi),((Camptoloma_smithii,Phelsuma_siebenrocki),((Gonyosoma_elaphus,Phylloscopus_squaterola),Pterocles_linaria))),Leiopython_cingulata),Pelodytes_pardus),(Bombyx_lobatus,Ptychozoon_septentrionalis)),(((((((((((((((Acipenser_subruficollis,((((Anthropoidae_calamita,Gavia_terrestris),(((((((Arenaria_jubata,Milvus_epops),((Elseya_odoratus,Sericinus_ammon),Macrorhamphus_martensi)),Pandion_hendricksoni),(Chrttusia_leucocephala,Spermophilus_sp)),((Citellus_acanthinura,Psalmopoeus_hirundo),Plegadis_vitulina)),((Chrysemys_tristis,(Holaspis_squamatus,Madagascarophis_barbatus)),((Gekko_leucotus,Myotis_deremensis),Otis_coelestinus))),(Diomedea_chukar,Thecla_hongkongensis))),(Eirenis_sirtalis,Rhodostethia_tolai)),(Chettussia_shadini,(((Ciconia_caesius,Gavia_albicilla),(Iguana_collectivus,Limosa_hasselquistii)),Colaeus_brevipes)))),Tadorna_barroni),Streptopelia_melanuroides),Athene_colombianus),Geochelone_alpinus),Erpeton_clarus),((((Capeila_fiber,Riparia_sirtalis),Pseudorca_clinatus),Riparia_savignii),Scolopendra_isabellina)),Saga_capreolus),Litoria_spinifera),((Cygnopsis_leucomystax,Lasiodora_rupestris),Desnana_krueperi)),(Anthropoides_decor,(Ctenosaura_coloratovillosum,Mergus_stylifer))),(((Haliaetus_macularius,Nerodia_kingii),Regulus_albertisii),Pelodytes_rosea)),Hyperoodon_macqueni),Alloporus_cinclus),(((Canis_godlewskii,Platalea_anatina),Phylloscopus_cyanogenys),Capella_dactylisonans)))),(((((((((Acanthis_nippon,(Chlamydotis_communis,Mylopharyngodon_deminutus)),(((Chen_reticulatus,Philacte_paganus),((Homopholis_pedo,Hysterocrates_perdix),Pareas_avinivi)),((Circus_filipjevi,Pagophila_lutra),(Middendorffinaia_vegans,Pterinochilus_pugatshuki)))),Corytophanes_mycterizans),(Candoia_dahurica,(Charadrius_celeber,Salvelinus_lepturus))),((Cuon_sinensis,(Odobenus_cocincinus,Odonthurus_insignis)),Falco_aureola)),Equus_metallica),Natriciteres_leucorodia),(((((((((((Alpes_lutra,(Enhudra_ruficollis,Spizaetus_molurus)),((Circaetus_Anas,(Coenobita_teguixin,(Sericinus_fuliginosus,Sitta_montela))),Latastia_homeana)),Corallus_eximia),Fulica_pica),Iguana_orientalis),Morelia_godlewskii),Dendrobates_turtor),Gerrhosaurus_dispar),Nerodia_corsac),((((((((Bradypterus_grossmani,Rhamphiophis_himalayanus),Scaphiopus_barroni),Fregilegus_dorsalis),Carabus_stejnegeri),Ciconia_gebleri),Ceratophrys_lagopus),Diomedea_temminckii),Passer_arseniavi)),(Enhydra_carinata,Pseudorca_torquata))),(Gongylophis_homeana,Grus_carnivorus))),Chettussia_oxycephalum),(Hottentotta_mystacinus,Phalaropus_franckii))),Pyrgilauda_temminckii),(Brachyramphus_colchicus,(Notophthalmus_scalaris,Scorpio_decorus))),Leiopython_schreibersi),((Charadrius_indica,Seokia_odoratus),Monodon_aristotelis)),(Lagenorhynchus_decorus,Scolopax_jacksoni)),Mareca_prominanus),(((((Alpes_monorhis,((((((Glareola_carolinensis,(Passer_grossmani,Pelusios_leucomystax)),Phyllopneuste_fimbriatus),Lasiodora_baibacina),Gongylophis_truncatus),Rosalia_veredus),Leiocephalus_acanthinura)),Sturnus_quinquestriatus),((Budytes_glottis,(((Chalcides_hispida,Rissa_rufinus),(((Notophthalmus_getula,Phrynops_argali),Underwoodisaurus_korschun),Sericinus_dahurica)),Scorpio_martensi)),(Madagascarophis_bengkuluensis,Vanellus_collaris))),Androctonus_aegyptia),(((((Ameiva_brevipes,Phormictopus_vanellus),Anas_ulikovskii),((Chettussia_nasuta,(Cyclemys_climacophora,Odobenus_tentaculatum)),(Vipera_means,Vulpanser_geniculata))),(Ameiva_rapax,(Eryx_cambridgei,((Iomachus_tetrix,Regulus_virgo),Porphyrio_tadorna)))),Felis_campestris))),((((Corvus_acanthinura,Iomachus_keyzerlingii),(Desnana_cranwelli,Thecla_maurus)),Eudrornias_albirostris),Nucifraga_subniger)),Osteopilus_nigrolineatus),((((((((((((((((((((Abantias_tataricus,Almo_ridibundus),Dipsosaurus_altaicus),Lepidobatrachus_baeri),((((((((((((((((((((((Acanthoceros_carbonaria,(Eudramias_squaterola,Pelecanus_linaria)),Dyscophus_paradoxus),(Meles_canus,Platemys_pictus)),Rissa_grunniens),(Aix_leucomystax,((((Gecarcinus_tuberculosus,Notophthalmus_ocellatus),Mergus_schrencki),((Gonocephalus_strepera,Psalmopoeus_monorhis),Phalacrocorax_scripta)),Ursus_adspersus))),(Anodonta_keyzerlingii,Chamaeleo_hypoleucos)),((Balaenoptera_leucorodia,((Coturnix_cyanogenys,Nyroca_tetrix),Thymallus_manul)),Tetrao_fallax)),Sceloporus_subglobosa),Teratolepis_sauromates),((Avicularia_ichthyaetus,Coregonus_stellio),Gecarcinus_percnopterus)),(Amphiuma_mystacinus,((Coenobita_hendricksoni,Teratolepis_emilia),(Lepidobatrachus_dexter,Limnodromus_auratus)))),Scolopendra_himalayanus),Grampus_porphyrio),(Corvus_duplex,(Picus_cinereus,Thamnophis_grandis))),((((((Alauda_novaeangliae,Nhandu_hosii),(((((Ardea_caryocatactes,Podoces_veredus),Ovis_duplus),(Halichoerus_erythrogastra,(Natriciteres_clypeatus,Nhandu_alterna))),(Columba_picta,Cuora_scalaris)),((Eublepharis_viridis,Ursus_japonensis),Ovis_zenobia))),Brachyramphus_querquedula),Coturnix_guttata),((Aythya_corsac,Circaetus_felderi),(Corvus_jaspidea,(Emberiza_duplus,Grampus_bewickii)))),(Chlidonias_cornix,Mergus_vertebralis))),Eumeces_argali),Ruticilla_cocincinus),((((Antilope_resinifictrix,((Atrophaneura_alpestris,Tryngites_ichthyaetus),((Oceanodroma_rutila,Parus_scabra),Otis_cioides))),(Ctenotus_hendersoni,(Norops_vulpes,Perdix_trianguligerus))),Rhacophorus_calamita),Dendrelaphis_querquedula)),Rangifer_bairdi),((Buthacus_pachypus,Nemorhaedus_grunniens),Net_trianguligerus)),(Porphyrio_chuatsi,Theloderma_picta)),(Branta_quinquestriatus,Trapelus_salvator))),Totanus_perrotetii),Fulica_dendrophila),Aythia_sauromates),Ophisops_arenarius),(Arctomys_fusca,Cynops_subcinctus)),(Lyrurus_hypomelus,Nemorhaedus_ocellatus)),(Meles_mexicana,Plegadis_alterna)),Pachydactylus_hyperboreus),(Emberiza_fasciata,Lanius_trigonopodus)),Ardea_means),Nipponia_rhymnus),((((((((((Acanthoceros_moschiferus,Alopex_mirabilis),Coenobita_subniger),Phalacrocorax_rubicola),Ethmostigmus_parreyssi),(Buthacus_flava,(((Moschus_weliczkowskii,Panthera_solitaria),Zosterops_variegatus),Picus_timidus))),Homopholis_catenifer),Chlamydotis_madagascariensis),((((((Aythia_siebenrocki,Hyla_deserti),((((Cottus_mystaceus,Lagenorhynchus_fimbriatus),Megophrys_guttata),Parus_carbo),Pelecanus_chukar)),Eutamias_brevirostris),(((Capreolus_africanus,Chelus_clericalis),Cottus_ibera),(Chettussia_lesueurii,Gallinago_gemmicincta))),Gallinago_fragrans),Capra_chinensis)),Macrorhamphus_fluviatilis),((((((((((((((((((((((Accipiter_paradoxus,((Boa_hosii,Glareola_longipes),(Totanus_grupus,Trapelus_triangulum))),Ptyodactylus_ovata),Pyrrhocorax_eremita),Actitis_walti),((((((Alcedo_irregularis,Alpes_ruficollis),(Dahurinaia_noctua,Mochlus_dauricus)),Vanellus_kopsteini),Limnodromus_decor),Rhabdophis_lavaretus),Haliaetus_solitaria)),(((((((((((Actitis_rubicola,Rhabdophis_mexicanum),Hydrochelidon_nasicus),Morelia_cranwelli),Chlamydotis_acuta),((((Ardea_picta,Ctenotus_virgo),Psammophis_hypoleucos),Phyllopneuste_leucocephala),Saiga_purpurascens)),(Branta_monilis,Capra_ridibundus)),(Tetrao_baeri,Trachemys_marinus)),Phylloscopus_coloratovillosum),Eunectes_dendrophila),Perdix_hosii),((((((((((Alauda_angulifer,(Micropalama_difficilis,Net_niloticus)),(Apus_argentatus,(((((Aythya_musculus,Otocoris_mnemosyne),Eurynorhynchus_apus),Eudrornias_tigris),Vormela_ampullatus),Sitta_alterna))),((Euspiza_albertisii,(Hyperoodon_dennysii,Natriciteres_rapax)),Testudo_caryocatactes)),Oedura_hyemalis),((Aythia_jaspidea,Osmoderma_brachydactyla),Natriciteres_breitensteini)),Bombycilla_anachoreta),Megophrys_politus),(Gonyosoma_physalus,Gyps_guineti)),Hydrochelidon_prasina),((Buthus_edulis,(Myotis_haliaetus,Zosterops_borealis)),Euspiza_rusticolus)))),Polypedates_capra),Caiman_limosa),((Bradyporus_rufus,(Gallinago_dorsalis,Pogona_classicus)),Phrynomerus_haliaetus)),Ptyodactylus_licin),Circus_quinquetaeniata),(((Antilope_interiorata,(Ninox_ciliatus,Siniperca_campestris)),Telescopus_atra),Vormela_viridis)),Grus_eulophotes),Eudrornias_cherrug),Bufo_cyanus),Buteo_acutus),(((((((((((((((((((((((Aegialifes_sanguinolentus,Aegialites_completus),((Desnana_sibirica,(Rissa_americanus,Upupa_hongkongensis)),Perdix_zenobia)),Rufibrenta_graeca),Litoria_ornata),Ptychozoon_communis),Hadrurus_cenchria),Nyctaalus_smithii),Philacte_felderi),Psalmopoeus_picta),((((Aix_canus,((Calotes_cristatus,((Moschus_tetrix,Prunella_cachinans),Tropidurus_erythronotus)),(Charadrius_decor,Gazella_fallax))),(Mustela_parreyssi,Sceloporus_virgo)),Certhia_calamita),(Capeila_cristatella,Telescopus_arcticus))),Thymallus_rudicolis),Teratolepis_deserti),(Agama_vittatus,(Columba_teguixin,Rhynchophis_euptilura))),Ortigometra_squaterola),(Otocoris_venulosa,Picus_tristis)),(((Haliaetus_leiosoma,Syrrhaptes_kurilensis),((Lepus_colchicus,Phelsuma_blakistoni),Litoria_vermiculatus)),Mesoplodon_atthis)),Sorex_chinensis),Fuligula_squaterola),Hottentotta_piceus),((((((((((((((Antaresia_fuscus,Trachemys_gigas),Grammostola_pelagicus),Cyriopagopus_monorhis),(Sus_turtur,Varanus_sibilans)),Nyroca_tuberculosus),Leuciscus_schneideri),Ciconia_radiata),(Bradypterus_ovata,Gazella_vereda)),Synthliboramphus_pardalis),((Chettussia_cornix,Gypaetus_gallicus),Margaritifera_eremita)),(Bombus_argali,(Bubulcus_glareola,(Oxyura_keyzerlingii,Pyrrhocorax_cherrug)))),Dryobates_stejnegeri),(Buthus_garullus,Megaptera_oxycephalum)),Dipus_veredus)),Eunectes_communis),Eremophila_galeatus),((Hottentotta_parahybana,Kinixys_marmorata),Hysterocrates_brongersmai))),Eudramias_indica),(Limnaeus_cachinans,Saga_salvator)),(Mogera_flavescens,Poephagus_atthis)),Pterocles_platycephala),Scaphiophryne_salamandra))),((((((((Aix_cinaedus,Phelsuma_naumanni),(Cervus_turtur,Kinixys_avinivi)),Nipponia_leuconotus),(Equus_ichthyaetus,Iguana_melanostictus)),Leiopython_ferrumequinum),(Bombus_cavimanus,Hemitheconyx_dentata)),Mabuya_brongersmai),(((Alcedo_penelope,(((((Alpes_collectivus,(((Certhia_leucogaster,Circaetus_kurilensis),Phrynohyas_montela),(Rhodostethia_undulata,Turdus_erythrogastra))),(((((Ardea_salamandra,(((Limnaeus_albopillosum,Thecla_casualis),Tupinambus_himalayanus),Oligodon_crispus)),Vipera_celer),Chelus_anachoreta),Eryx_melanostictus),Gypaetus_totanus)),Chalcides_smithi),Aythia_truncatus),Mareca_rosea)),(Anodonta_kingii,Cervus_longicollis)),Otocoris_sinensis))),Nerodia_homeana),Euspiza_blakistoni),((Chelydra_virgo,Felis_fulva),Felis_albicilla))),(((((Aquila_infrafrenata,((((((Balaena_citreola,((((Dryobates_armeniacus,Procellaria_platycephala),Scaphiopus_cinaedus),Oligodon_leschenaultii),Mylopharyngodon_ion)),Machetes_merganser),((Cottus_fulva,Coturnix_australis),Selenocosmia_arenarius)),Fulica_torquatus),Testudo_leucoptera),(Hottentotta_obsoleta,Mochlus_spinifera))),(Gazella_pusilla,Mylopharyngodon_martensi)),Lagenorhynchus_viridescens),((Bradyporus_holbrooki,Ceratophrys_resinifictrix),Gonocephalus_dominicus)),(Bradypodion_reinwardti,(Chen_schreibersi,Natriciteres_licin)))),(Thamnophis_vereda,Triturus_melleri)),((Dasypeltis_fuliginosus,((Ketupa_crassicauda,Uroplatus_enydris),Seokia_maldivarum)),Phormictopus_vipio)),Porphyrio_climacophora),(Corallus_aestivus,Eutamias_decor)),Physignathus_alpestris),(((((Alpes_boulengeri,(Anodonta_constrictor,(Minipterus_madagascariensis,Pica_canus))),(Lepus_euptilura,Uncia_leuconotus)),Eremophila_caucasicus),Pelusios_calvus),Babycurus_elaphus)),(Bubulcus_garmani,Ephibolus_porphyrio)),Morelia_hypomelus),(Furcifer_mugodjaricus,(Macrorhamphus_similis,Philacte_botnica))),((Haliaetus_grupus,Pratincola_uncia),Thecla_cingulata)),(Micropalama_geyri,Oligodon_argentatus)),Physignathus_melleri),(Athene_seemani,(Cervus_ion,Charadrius_aspera))),((Acanthoscurria_linaria,Gecarcinus_fasciata),Enhydra_dispar)),((Charadrius_marinus,Netta_cepediana),(Glareola_schneideri,Lycodon_hasselquistii))),Pandion_dignus),Megophrys_cinclus),((Chelus_ferox,Rhacodactylus_edulis),Epipedobates_pallidus)),Phylloscopus_rapax),Litoria_casualis)),Megaloperdix_murinus),Basiliscus_rosmarus),(((((((((((((((((((((((((((((((Abantias_fuscus,(Netta_fissipes,Rhacodactylus_occitanus)),Neolycaena_multituberculatus),((((Acipenser_mitratus,Eutamias_agama),Pyrrhocorax_diadema),Meles_crassidens),(Phrynohyas_jaspidea,Triturus_pyromelana))),(((((((((((Allobates_bonasus,Leptopelis_noctua),((Branta_boyciana,Holaspis_morinellus),Sturnus_morinellus)),Ketupa_haliaetus),Upupa_docilis),Platemys_vanellus),((((Capella_glottis,Gongylophis_cyanea),Fregilegus_pugatshuki),Xenopeltis_musculus),Lamprolepis_standingii)),Capreolus_deminutus),(Net_taxus,Ruticilla_hendricksoni)),Desnana_euptilura),Morelia_acutus),Budytes_hodgsoni)),(Cygnus_circia,Kinixys_saiga)),Turdus_ocellatus),Tetrao_exquisita),Underwoodisaurus_wislizeni),(Calidris_ammon,Falco_varius)),Petrocincla_peregrinus),Cuon_garulla),((Anser_cynodon,(Monticola_doriae,Squaterola_seemani)),Crotaphytus_novaeangliae)),((Chrttusia_situla,Grammostola_ibis),(Hirundo_avosetta,Querquedula_dubia))),(Corytophanes_heliaca,Passer_gallinago)),((((((((((((((((((((((Aegialites_ignicapillus,(Phalaropus_elaphus,Sphenops_hendersoni)),Picus_kazanakowi),(Allactaga_imperator,Nemachilus_cepediana)),((Alcedo_seemani,(Anas_leiosoma,(Cuculus_odoratus,Pica_fiber))),Sphenops_rubida)),Hottentotta_picta),Haplopelma_vittatus),((((Antaresia_soloensis,(((Balaenoptera_pygmeus,Lutra_sudanensis),Ciconia_caelebs),Eurynorhynchus_obsoleta)),((((Arctomys_monoceros,Siniperca_albocinctus),(Cynops_peregusna,Pelodytes_leucopsis)),Hadrurus_circia),Vulpanser_vitticeps)),((((((((((((((((((((((((((Anthropoidae_dominus,Cygnopsis_oedicnemus),(((Circus_notaeus,Sericinus_conicus),(Thymallus_graeca,Tiliqua_ichthyaetus)),Clemmys_equestris)),Zosterops_clypeata),(Erpeton_caninus,Phrynohyas_aureostriata)),Underwoodisaurus_mehelyi),Bronchocela_longipes),((Gallinago_falcipennis,Triturus_yeltoniensis),(Ingerophrynus_decor,Scorpio_hispida))),(((Bradypterus_torquatus,Procellaria_zagrosensis),(Pedostibes_climacophora,Scolopendra_temminskii)),(Notophthalmus_cristatella,Rufibrenta_dolosus))),Nhandu_versicolor),Emberiza_ferina),((((Callipogon_horridum,(((Nipponia_personata,Porzana_leucorodia),(Podoces_monilis,Podoces_mystacinus)),Phylloscopus_saxatilis)),Cynops_blythi),Egretta_arseniavi),((Circaetus_jaculus,Ophisops_difficilis),Paramesotriton_septentrionalis))),Psalmopoeus_wislizeni),Eucratoscelus_monoceros),(Osmoderma_interpres,(Salmo_sp,Tamias_scalaris))),Milvus_gallinago),Ovis_daurica),Otis_leucopsis),Pyrgilauda_cyanochloris),Tupinambus_mugodjaricus),((((((Anthropoides_chukar,((Eutamias_musicus,Sterna_gallicus),Myotis_elaphus)),Melanocorypha_borealis),Teratoscincus_taxus),(Balaenoptera_lutris,(Chlidonias_pendulinus,Melanocoryhpa_tristis))),(Phelsuma_angulifer,Zosterops_vanellus)),((((Apalone_baeri,Nemorhaedus_heudei),((Leiocephalus_auriculatus,Notophthalmus_dolosus),Saga_flavirufa)),(Hyperoodon_hungaricus,Hyperoodon_orientalis)),((((Aplopeltura_cygnus,(((Eumeces_flammea,(((((Grus_rufinus,Mesoplodon_monorhis),Scolopendra_cristatellus),Tamias_decor),Totanus_morinellus),Pusa_sibiricus)),Ziphius_semipalmatus),Squaterola_spilota)),(Bombycilla_licin,(Larus_drapiezii,sibiricus_dispar))),(((Argynnis_cranwelli,Nucifraga_clericalis),Dasypeltis_isabellina),(((Calotes_iankowskii,Lamprolepis_leporosum),Norops_govinda),Tiliqua_irregularis))),(Apus_auratus,Natriciteres_marmorata))))),Pachytriton_canorus),Seokia_marinus),(Camptoloma_fallax,Pituophis_acuta)),Babycurus_variabilis),Apus_torquatus),Fregilegus_jaculus)),Moschus_epops)),Lamprophis_citreola),(Bronchocela_flava,Mesoplodon_adspersus)),Gazella_naumanni),(Osmoderma_garullus,Trionyx_giganteus)),Ephibolus_atra),(((Myotis_nasicus,Testudo_clypeata),Scolopendra_lutra),Pyxicephalus_wislizeni)),Uromastyx_dispar),Chrysopelea_bicoloratum),(Almo_rudicolis,(Ninox_hardwickii,Parus_arvensis))),Alopex_graeca),Milvus_leucomystax),Lanius_circia),((Falco_mlokosiewiczi,Middendorffinaia_brongersmai),Haplopelma_canorus)),Liasis_govinda),(Hydrochelidon_penelope,Ptyodactylus_prasina))),(Capreolus_crocodilus,(Hadogenes_chinensis,Neolycaena_leucoryphus))),(Acanthoceros_prominanus,(Butastur_jaspidea,Phyllopneuste_brandtii))),(((((((((((((((((Acanthis_alpestris,((((((((((((((((((Acanthis_cherrug,Lagenorhynchus_acutus),Rhombomys_pholeter),(Ambystoma_viridis,(((Cardiocranius_sebae,(Phyllopneuste_pugatshuki,Terpsihone_cyanogaster)),((Emydura_spinifera,Limosa_platycephala),Haliaetus_dauricus)),(Cuculus_lesueurii,Laudakia_siebenrocki)))),((Bronchocela_spilota,((((Iomachus_labiatus,Moschus_macrops),Perdix_reinwardti),Rhesus_melleri),Meles_sebae)),Oenanthe_bewickii)),(((Buthus_tolai,(Calidris_tricolor,Parus_ferox)),Eubalaena_ameiva),Upupa_aeruginosus)),(Antilope_decor,Himantopus_cristata)),Elseya_terrestris),(Erpeton_mugodjaricus,Laudakia_fluviatilis)),(((((((Aegypius_garmani,(Corallus_minutus,Eulabeia_canus)),Scaphiophryne_ibis),Ephibolus_fiber),(Melanocorypha_yeltoniensis,Oxyura_pendulinus)),Pelecanus_dignus),Odonthurus_stellatum),Theloderma_cynodon)),Net_vulpes),Neophron_marmoratus),(((((Buthus_indica,(((Casarca_bengalensis,Limnodromus_himalayanus),Cypselus_atriceps),Theloderma_vulpes)),(Coenobita_moschata,((((((Enhydra_kingii,(((Furcifer_fallax,Selenocosmia_comicus),((Seokia_oenanthe,Varanus_cocincinus),(Sternotherus_carnifex,Testudo_constricticollis))),Laudakia_fallax)),Ninox_marcianus),Paraphysa_sujfunensis),Osmoderma_bengalensis),(((Ethmostigmus_hendricksoni,Natriciteres_deminutus),Querquedula_leucophyllata),Petrocincla_onocrotalus)),Net_bukhunensis))),(Corvus_longipennis,(Elseya_cyanus,Sphenurus_moschata))),Oligodon_temminskii),(Ephibolus_hypomelus,Prunella_niloticus))),Sturnus_monorhis),(((((((((((((Acanthoceros_jacksoni,Dendrelaphis_uncia),Lycaenopsis_caninus),(((((Aegialifes_hirundo,Chen_melanuroides),Aythya_argentatus),Burhinus_arvensis),(Caiman_arcticus,(Hemiscorpius_spilota,Pareas_avicularia))),Boa_carolinensis)),Hadogenes_musicus),Ctenotus_sudanensis),Ctenosaura_unicolor),((((((Acanthogonatus_limosa,(Cardiocranius_reinwardti,Platemys_crispus)),(((((((Acanthogonatus_minutus,(((((((((((Actitis_pugatshuki,Lyrurus_spaldingi),Mogera_keyzerlingii),Phrynomerus_mystaceus),(((Amphiuma_plumifrons,Anthropoidae_aegagrus),((((((Dipsosaurus_pachypus,Odobenus_barroni),((Eumeces_pulchra,Moschus_rosea),Querquedula_asperum)),(Haplopelma_cynodon,Leptobrachium_tricolor)),Siniperca_physalus),Terpsihone_cygnus),(Halichoerus_septentrionalis,Margaritifera_undulata))),((Paramesotriton_calligaster,Pyrgilauda_heliaca),Rhacophorus_mirabilis))),(Boiga_helena,Eunectes_cingulata)),Phalacrocorax_avocetta),Siniperca_variegatus),(Carabus_cornix,Teratoscincus_picta)),Ziphius_riparia),(((((Almo_pugnax,Odobenus_colchicus),((Erpeton_Jankowskii,((Monticola_ferruginea,Norops_avosetta),Nemachilus_cornix)),Phelsuma_dominicus)),Tetrao_canorus),Gyps_leschenaultii),Alpes_nebularia)),Litoria_boschas)),(Ahaetulla_brevipes,(((((Clemmys_turtur,(((Cygnus_vermiculatus,Porzana_leucomystax),Tropidurus_arseniavi),Gallinago_pachypus)),(Pyxicephalus_porzana,Upupa_guttata)),(Rhacophorus_bedriagai,Vipera_epops)),Syrrhaptes_baibacina),Vormela_albatrus))),(((Chrysemys_pugatshuki,Machetes_picta),Rhabdophis_bobac),((Neolycaena_caesius,Vulpanser_alpinus),Salvelinus_cancerides))),Turdus_modestus),Burhinus_guttifer),Rhynchaspis_pygmaeus),Marmota_noctua)),((((((Canis_fuscatus,Paraphysa_cygnus),Gambelia_angustirostris),Phoca_fischeri),Streptopelia_cornix),(((Cyriopagopus_caryocatactes,Larus_gigas),(Phasianus_rutila,Phelsuma_ulikovskii)),Otis_chukar)),(Elseya_glacialis,(Leiocephalus_gebleri,Streptopelia_crassidens)))),((Eumeces_guttifer,Macrorhamphus_subrubrum),Fulica_obsoleta)),Fregilegus_scincoides),Grus_duplex)),((((((((Aegialites_leucostomum,(Margaritifera_hassanica,Pachytriton_vegans)),Chrttusia_aceras),Apus_hardwickii),Testudo_hyperboreus),Teratolepis_bonasus),Dyscophus_clypeata),(Ambystoma_turtur,((Brachyramphus_obsoleta,((Chondropython_uluguruensis,Fregilegus_caudata),(Paramesotriton_casualis,Pogona_cygnus))),((Gerrhosaurus_Bernicla,((Haplopelma_wumuzusume,Norops_jaspidea),(Netta_opimus,Scaphiopus_compactus))),Kinosternon_ferox)))),Kinosternon_plumifrons)),Scorpio_nivicola),Bronchocela_dennysii),((((((((((((Acanthogonatus_occitanus,(((((((((((Aegialites_zagrosensis,((Avicularia_leucotus,Net_haliaetus),(Chrysemys_rudicolis,Uncia_porphyrio))),(Eremophila_guttata,Kinosternon_venulosa)),(((Arenaria_catenifer,Dasypeltis_flavolineata),Netta_circia),((((Capra_flavirufa,Enhydris_grus),Kinosternon_tenuirostris),Osteopilus_chinensis),Zosterops_insignis))),((Ingerophrynus_marcianus,(Netta_zagrosensis,Testudo_rostratus)),Pyxicephalus_orientalis)),Pratincola_sirtalis),Grammostola_hassanica),((((Chlamydosaurus_himantopus,Nyctixalus_multifasciata),Melanocoryhpa_guangxiensis),Micropalama_leschenaultii),(Cottus_leptochelis,(Motacilla_exquisita,(Netta_tentaculatum,Xenopeltis_plathyrhychos))))),Alopex_schneideri),Ninox_scincoides),(Philacte_longipennis,((Pratincola_uluguruensis,(Pterocles_angustirostris,Spalerosophis_mehelyi)),Scincus_dulkeitiana))),Chlidonias_acanthinura)),(((Alpes_moschiferus,Dendrobates_corone),Spalax_dives),Platemys_lehmanni)),((((((((Alpes_chinensis,Tetraogallus_bengkuluensis),(Aplopeltura_caeruleus,(Hirundo_glareola,Pelodytes_comicus))),(Boa_boschas,Corvus_bengkuluensis)),Minipterus_pulcher),Tryngites_himantopus),(Boiga_lineatus,Poephagus_deremensis)),Haliaetus_hemilasius),Charadrius_dendrophila)),Selenocosmia_monoceros),Ptyodactylus_scabra),Uncia_cingulata),(Iomachus_vermiculatus,(Pagophila_brachydactyla,(Phylloscopus_castaneus,Scolopendra_subrubrum)))),((Mylopharyngodon_deserti,Spermophilus_aceras),Pyrgilauda_taczanowskius)),Rhynchophis_coturnix),((Dasypeltis_rupestris,Gonocephalus_grus),Oenanthe_dione)),((Buthacus_brongersmai,Plegadis_dubia),Sceloporus_bellii)),(((((Arctomys_sebae,Rhynchophis_rosea),(((Chrysopelea_monacha,((((Cuora_sirtalis,Lamprolepis_dulkeitiana),Liasis_vertebralis),(Enhydris_rupestris,Mogera_lopatini)),Halichoerus_sanguinolentus)),Vanellus_paradisi),(Lamprolepis_eximia,Sorex_subrubrum))),Boiga_constricticollis),Eutamias_pulcher),(((Branta_albicilla,Ovis_margaritifera),(Gecarcinus_smaragdina,(((Hyla_eburnea,Madagascarophis_porphyrio),Rhacophorus_eburnea),Plethodon_albigula))),(Enhudra_cristatella,((Ninox_leschenaultii,Synthliboramphus_miliaris),Otis_lobatus)))))),((Hyla_turneri,Litoria_enydris),Lamprolepis_gibbosus)),((((Aegypius_euptilura,(((Chettussia_hypoleucus,Riparia_orientalis),Norops_garmani),Cuculus_bonasus)),Ziphius_fulvus),Sternotherus_tetrix),Nipponia_undulata))),((((((((Acipenser_boulengeri,Desnana_ciliatus),((Chrttusia_hodgsoni,Poephagus_helena),(Hottentotta_argentatus,Rosalia_mandarina))),Rhacophorus_marinus),(((Athene_minutus,Melanocoryhpa_leucostomum),Margaritifera_buccata),Streptopelia_duplus)),(Basiliscus_sibilans,((Lycaenopsis_doctus,(Odobenus_brongersmai,Salamandra_duplex)),Querquedula_wogura))),(Leuciscus_medici,(Saxicola_rupestris,Xenophrys_grandis))),Xenochrophis_climacophora),Enhudra_bairdi)),((Lycodon_paradisi,Rangifer_agama),(Pterocles_japonica,Pusa_serpentina))),(((Bombycilla_breitensteini,Norops_buccata),Tropidurus_calyptratus),Bronchocela_kraepelini)),Saxicola_armata)),Heterodon_grandis),((Eirenis_lavaretus,Streptopelia_pictus),Nemorhaedus_aureola)),((Boa_cristatellus,Milvus_platycephala),(Ketupa_hyemalis,Philacte_medirostris))),Passer_zonata),Squaterola_truncatus),Phormictopus_cygnus),Cypselus_crucigera),Sitta_armeniacus),Lanius_eximia),Anthropoidae_guttata),Cottus_brandtii),Opheodrys_mexicana),(((Dendrobates_cherrug,Remiz_falcipennis),Phrynomerus_picta),Sternotherus_mackloti)),Tadorna_atra),(Lycodon_amethistina,(Mochlus_Jankowskii,Physignathus_emarginatus))),((((((((((((((((((((((Acanthis_mykiss,(Lutra_porzana,Tylototriton_colchicus)),Anthropoides_flavolineata),Mesoplodon_ferrumequinum),(((Anas_albirostris,Phalaropus_personata),(Enhydra_flavigularis,Philacte_alba)),Grampus_lopatini)),((Alcedo_isabellina,Haliaeetus_parahybana),Chalcides_melanoleucus)),(((((((((((((((((((((((((((((((((Accipiter_carbo,(Iguana_striatus,(Paramesotriton_adamsii,Squaterola_anachoreta))),Syrrhaptes_gregaria),Athene_krueperi),Pusa_margaritifera),(Alpes_dives,(((Chrysopelea_franckii,Leuciscus_taxispilota),Platemys_rufus),Ctenosaura_vitulina))),(((Callipogon_alpina,(Picus_gallicus,Trachemys_venulosa)),(Clemmys_plathyrhychos,Fuligula_tentaculatum)),Enhudra_citreola)),Anser_torquatus),Eurynorhynchus_hypomelus),Tryngites_garullus),Leiurus_pica),(Kinixys_africanus,Saiga_dolosus)),Panthera_interpres),Rhabdophis_taeniura),Vipera_argali),(Boa_dentatus,Sphenurus_bukhunensis)),(Circus_imperator,Larus_scabra)),(Dafila_pica,Enhydra_bicinctores)),Tropidurus_sebae),(((((Charadrius_latiscutatus,Mesoplodon_mexicana),(Monticola_querquedula,Rhamphiophis_ocellatus)),Polypedates_Bernicla),(Falcipennis_guineti,Plegadis_melanoleucus)),Cottus_sibilans)),Ruticilla_stejnegeri),Pica_uluguruensis),(Chen_flammea,Sterna_cynodon)),(((Basiliscus_pachypus,Pachytriton_serricollis),Siniperca_ceterus),Rhinolophus_falcinellus)),(Gazella_parreyssi,Grus_enydris)),Cervus_mandarina),((((((((Anthropoidae_avosetta,(((Dyscophus_undulata,Eudrornias_schneideri),Lagenorhynchus_nigropalmatus),Monodon_hasselquistii)),((((Aplopeltura_gecko,Monticola_schokari),Pachytriton_minor),Capra_dauricus),Terpsihone_grus)),Nemorhaedus_wumuzusume),(Buthus_cinerea,(Hysterocrates_sieboldii,Pachydactylus_cyanus))),(Cinclus_flavirufa,Trionyx_armeniacus)),Ethmostigmus_tarda),Podoces_hyemalis),(((Charadrius_rostratus,Eucratoscelus_miliaris),Marmota_coturnix),Lystrophis_meermani))),Eirenis_catenifer),Dafila_crucigera),((Amphiuma_ferrumequinum,Lobipes_reticulatus),((Marmota_lavaretus,Tadorna_casualis),Spermophilus_pallidus))),Tropidurus_unicolor),((Capeila_emilia,Nerodia_niloticus),Nyctaalus_garulla)),((Allactaga_oxycephalum,Buthacus_arvensis),(((Aythya_circia,Chelydra_personata),(((Chalcides_baibacina,(Plethodon_turtur,Pseudemys_schneideri)),Phylloscopus_laevis),Lobipes_atrigularis)),(Cyriopagopus_durus,Tadorna_nebularia)))),Citellus_mystacinus)),(Eschrichtius_melanoleucus,(Lutra_subruficollis,Lycaenopsis_holbrooki))),(((Fulica_reticulatus,((Glareola_labiatus,Heterodon_nebularia),Mareca_carinata)),Pyrrhocorax_breitensteini),Pogona_nippon)),Caiman_uncia),((Dafila_standingii,(Phrynops_melanuroides,Python_plathyrhychos)),Dyscophus_arizonensis)),Micropalama_boschas),Pterinochilus_miliaris),((Chelus_bimaculata,(Chondropython_fernandi,Dahurinaia_rosea)),Haliaetus_rapax)),Anthropoidae_helena),Scaphiophryne_decorus),Numenius_borealis),(((((Apus_elaphus,(Middendorffinaia_compactus,(Pyxicephalus_erythropus,Rhinolophus_cornix))),(Budytes_nivalis,((Chamaeleo_cinclus,(Hadogenes_margaritifera,Riparia_getula)),Limnaeus_indicus))),Dasypeltis_caesius),(Balaena_tinctorius,(Euspiza_blythi,Oligodon_griseus))),Gongylophis_casualis)),Eurynorhynchus_himantopus),Pelomedusa_spaldingi),((((((Capella_himalayensis,Regulus_castaneus),Emydura_temminckii),Chlamydotis_glareola),(Chondropython_isabellina,Scaphiopus_cambridgei)),Capra_caesius),Odonthurus_ferruginea)),(Marmota_cornix,Pachytriton_alba)),Teratoscincus_interpres))),(Canis_atriceps,((Citellus_viridescens,Hydrosaurus_fallax),Phylloscopus_leptochelis))),(((((((((((((((((Ahaetulla_exanthematicus,Apalone_himantopus),Rhabdophis_olivacea),Monachus_irregularis),Oenanthe_crispus),(Rhesus_sibilans,Varanus_bengalensis)),Citellus_vereda),(((Camptoloma_cygnus,(Eunectes_tarda,Pandion_quadriocellata)),(Circaetus_fuliginosus,Rhinolophus_ferruginea)),Lagenorhynchus_alcinous)),Aix_nivicola),((Anodonta_deremensis,Pseudorca_nasuta),((Coturnix_spinifera,Varanus_caeruleus),Fulica_emarginatus))),(Tadorna_aristotelis,Teratolepis_venulosa)),((((Castor_clericalis,(((Chrttusia_spilota,(Picus_barbatus,Scaphiophryne_nigra)),Kinosternon_caudatus),Sericinus_aeruginosus)),((Chlamydosaurus_scrofa,Clemmys_ridibundus),Perdix_ampullatus)),Pituophis_duplus),Nhandu_flavolineata)),Netta_politus),(Corvus_sujfunensis,Phasianus_salei)),((Egretta_quadriocellata,Scolopendra_infrafrenata),Mochlus_alpinus)),Ninox_ussuriensis),((Balaena_cocincinus,Madagascarophis_leptochelis),(Lagenorhynchus_olivacea,Vormela_hilarii))),Coturnix_emilia)),Circus_insularis),Larus_bairdi),((((((((Actitis_maculatum,Furcifer_subglobosa),Phelsuma_tetrax),Eremophila_serricollis),Chelodina_salei),Glareola_siebenrocki),(((((((((((((Apodora_helena,(Grus_chinensis,(Pyxicephalus_unicolor,Spizaetus_maritimus))),Mesoplodon_picta),Grampus_tetrax),((Leiopython_kazanakowi,Lepidobatrachus_maculatum),Phyllopneuste_ridibundus)),(((((((Cinclus_mongolica,Pratincola_hasselquistii),(Dendrelaphis_quinquetaeniata,Odobenus_hypoleucos)),Uroplatus_casualis),(Equus_citrsola,Morelia_miliaris)),Megophrys_baeri),Scolopax_gobio),Ctenosaura_venulosa)),(Crocodylus_ovata,Squaterola_vitticeps)),Leiocephalus_melonotis),Boiga_vipio),(Pseudemys_rhymnus,Sterna_iankowskii)),(Hyla_maritimus,Machetes_sagrei)),Eudramias_cristata),Ctenosaura_squamatus),Eucratoscelus_nasuta)),((Alectoris_ibera,Nipponia_scabra),(Hirundo_canagica,sibiricus_dominicus))),Tadorna_scutulata)),Alectoris_atrigularis),((Aix_penelope,Callipogon_ridibundus),(Euspiza_arvensis,Motacilla_vittatus))),Middendorffinaia_erythronota),(Philomachus_exquisita,sibiricus_gecko)),(Corytophanes_soloensis,((Grammostola_marinus,sibiricus_davidiana),Polypedates_longipes))),Terpsihone_virgo),Lagenorhynchus_intermedia),Cygnopsis_castus));'

taxa = sorted(taxon for taxon in re.split('[(),]+', newick.rstrip(';')) if taxon)

#print(taxa)

chtblist = create_a_character_table(newick)

#print(chtblist)

# %%
import itertools as it
import sys

quartets = set()

for l in chtblist:
    C, D = set(), set()
    for i, ch in enumerate(l):
        if ch == '0':
            C.add(taxa[i])
        elif ch == '1':
            D.add(taxa[i])
    for A in it.combinations(C,2):
        for B in it.combinations(D,2):
            a = tuple(sorted(A))
            b = tuple(sorted(B))
            #print(a,b)
            if (a,b) not in quartets and (b,a) not in quartets:
                quartets|= set([(a,b)]) 
#print(quartets)
print(len(quartets))
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 2201, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#         etype, value, tb, tb_offset=tb_offset
#     )
#   File "/lib/python3.13/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#
#         self, etype, evalue, etb, tb_offset, context
#     )
#   File "/lib/python3.13/site-packages/IPython/core/ultratb.py", line 1064, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self, etype, evalue, etb, tb_offset, context
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/lib/python3.13/site-packages/IPython/core/ultratb.py", line 872, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
# ...

# %%
tempa = {(0,1),(0,2),(1,2)}
tempb = {(0,2),(0,3),(2,4)}
from itertools import product
print(list(product(tempa,tempb)))
print(set(product(tempa,tempb)))
print(len(list(product(tempa,tempb))))
print(len(set(product(tempa,tempb))))
# Out:
# [((1, 2), (0, 3)), ((1, 2), (0, 2)), ((1, 2), (2, 4)), ((0, 2), (0, 3)), ((0, 2), (0, 2)), ((0, 2), (2, 4)), ((0, 1), (0, 3)), ((0, 1), (0, 2)), ((0, 1), (2, 4))]
# {((0, 1), (0, 2)), ((0, 2), (0, 2)), ((0, 2), (0, 3)), ((1, 2), (2, 4)), ((0, 1), (2, 4)), ((1, 2), (0, 3)), ((0, 1), (0, 3)), ((0, 2), (2, 4)), ((1, 2), (0, 2))}
# 9
# 9

# %%
import itertools as it
import sys


for l in chtblist:
    C, D = set(), set()
    for i, ch in enumerate(l):
        if ch == '0':
            C.add(taxa[i])
        elif ch == '1':
            D.add(taxa[i])
            
    from itertools import product
    #print(list(product(it.combinations(C,2),it.combinations(D,2))))
    print(len(set(product(it.combinations(C,2),it.combinations(D,2)))))
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 2201, in showtraceback
#   File "/lib/python3.13/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#   File "/lib/python3.13/site-packages/IPython/core/ultratb.py", line 1064, in structured_traceback
#   File "/lib/python3.13/site-packages/IPython/core/ultratb.py", line 872, in structured_traceback
#   File "/lib/python3.13/site-packages/IPython/core/ultratb.py", line 757, in format_exception_as_a_whole
#   File "/lib/python3.13/site-packages/IPython/core/ultratb.py", line 830, in get_records
#   File "/lib/python3.13/inspect.py", line 1019, in getmodule
# MemoryError

# %%
import itertools as it
import sys


for l in chtblist:
    C, D = set(), set()
    for i, ch in enumerate(l):
        if ch == '0':
            C.add(taxa[i])
        elif ch == '1':
            D.add(taxa[i])
            
    from scipy.special import comb
    print(comb(len(C),2))
    print(comb(len(D),2))
    print(comb(len(C),2)*comb(len(D),2))

# %%
n = 6
n = 4359
#from scipy.special import comb
#print(comb(n, 4) % 1000000)
print((n*(n-1)*(n-2)*(n-3)/4/3/2) % 1000000)
# Out:
# 113251.0

# %% [markdown]
# If there are nleaves, then we get the number of quartet is comb(n, 4) = n(n−1)(n−2)(n−3)/24
